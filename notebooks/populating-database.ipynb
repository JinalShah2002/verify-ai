# %% [markdown]
# # Populating Database
#
# In this notebook, I am populating the database with all the data. For this, I need to go through the data files I want to use and then see how they are set up and then insert rows in the table.

# %%
# Importing libraries
import pandas as pd
import re
import sys
import sqlalchemy

# Adding the credentials path
sys.path.append('../')
from credentials import credentials

# %% [markdown]
# ## Putting the different data sources into the table.
#
# In this section, I go through the different files I need for each data source and put it into table.

# %% [markdown]
# ### daigt data - llama 70b and falcon180b

# %%
# Getting the data csvs
falcon = pd.read_csv('../data/llama70b-and-falcon70b-generated/falcon_180b_v1.csv')
llama = pd.read_csv('../data/llama70b-and-falcon70b-generated/llama_70b_v2.csv',index_col=0)
combined = pd.read_csv('../data/llama70b-and-falcon70b-generated/llama_falcon_v3.csv')

# %%
# Viewing falcon generated
falcon.head(5) # Falcon doesn't have a column for LLM generated, need to add it
# Out:
#                                       generated_text  \
# 0  Dear Principal,\n\nI am writing to express my ...
# 1  When people are faced with a difficult decisio...
# 2  As a grade 12 student, I believe that summer p...
# 3  Dear Principal,\n\nI am writing to share my th...
# 4  "Making Mona Lisa Smile" is an interesting art...
#
#                                       writing_prompt
# 0  Your principal is considering changing school ...
# 1  When people ask for advice, they sometimes tal...
# 2  Some schools require students to complete summ...
# 3  Some of your friends perform community service...
# 4  In the article "Making Mona Lisa Smile," the a...

# %%
# Viewing llama generated
llama.head(5)
# Out:
#                                       generated_text  \
# 0  Dear State Senator,\n\nI'm writting to you tod...
# 1  Uh, hi! So, like, summers are, like, awesome r...
# 2  When peoples ask for advices, they sometimes t...
# 3  I think art edukation is super impotent for ki...
# 4  I think we should totally switch to renewable ...
#
#                                       writing_prompt  generated
# 0  Write a letter to your state senator in which ...          1
# 1  Some schools require students to complete summ...          1
# 2  When people ask for advice, they sometimes tal...          1
# 3  Many people believe that arts education is ess...          1
# 4  In recent years, there has been a push towards...          1

# %%
# Viewing combined generated
combined.head(5)
# Out:
#                                                 text  generated  \
# 0  One way we can make a positive change is by li...          1
# 1  The experimental district of Vauban in Germany...          1
# 2  The successful "Day Without Cars" event in Bog...          1
# 3  The exhaust from cars pollutes our air, and th...          1
# 4  Recently, Paris faced a severe pollution probl...          1
#
#        prompt_name      model
# 0  Car-free cities  llama_70b
# 1  Car-free cities  llama_70b
# 2  Car-free cities  llama_70b
# 3  Car-free cities  llama_70b
# 4  Car-free cities  llama_70b

# %%
# Want to see how many prompts I have in combined
combined['prompt_name'].value_counts() # 7 total prompts
# Out:
# prompt_name
# Car-free cities                     1000
# Does the electoral college work?    1000
# The Face on Mars                    1000
# "A Cowboy Who Rode the Waves"       1000
# Exploring Venus                     1000
# Facial action coding system         1000
# Driverless cars                     1000
# Name: count, dtype: int64

# %% [markdown]
# Based on initial analysis, falcon and llama dataframes are ready to be inserted into the table. The falcone dataframe just needs a generated column which is going to be set to all 1s. For the combined dataframe, I need to map the prompt_name to the prompts. Fortunately, the persuade 2.0 corpus provides a mapping, so I can utilize this mapping prior to adding the combined dataframe into the table.
#
# I also need a word count feature to add to the table. Hence, I need to add the word count feature.

# %%
# Adding a generated column in falcon
falcon['generated'] = 1
falcon.head(5)
# Out:
#                                       generated_text  \
# 0  Dear Principal,\n\nI am writing to express my ...
# 1  When people are faced with a difficult decisio...
# 2  As a grade 12 student, I believe that summer p...
# 3  Dear Principal,\n\nI am writing to share my th...
# 4  "Making Mona Lisa Smile" is an interesting art...
#
#                                       writing_prompt  generated
# 0  Your principal is considering changing school ...          1
# 1  When people ask for advice, they sometimes tal...          1
# 2  Some schools require students to complete summ...          1
# 3  Some of your friends perform community service...          1
# 4  In the article "Making Mona Lisa Smile," the a...          1

# %%
# Creating a function to get the word count of a piece of text
def get_word_count(text:str) -> int:
    """
    get_word_count

    A function to get the word count of some text.

    inputs:
    - text: a string that indicates you want to get the word count for.

    outputs:
    - an integer representing the word count
    """
    return len(re.findall(r'[a-zA-Z_]+',text))

# %%
# Adding a word count feature to the falcon dataset
falcon['word_count'] = falcon['generated_text'].apply(get_word_count)
falcon.tail(5)
# Out:
#                                          generated_text  \
# 1050  (I am not capable of personal opinions or beli...
# 1051  In "The Challenge of Exploring Venus," the aut...
# 1052  The article "Making Mona Lisa Smile" discusses...
# 1053  As a grade 6 student, I am still learning abou...
# 1054  Passage 1:\n\nCars are one of the main ways in...
#
#                                          writing_prompt  generated  word_count
# 1050  The role of zoos in conservation and education...          1         360
# 1051  In "The Challenge of Exploring Venus," the aut...          1         442
# 1052  In the article "Making Mona Lisa Smile," the a...          1         327
# 1053  The issue of gun control is a highly contentio...          1         313
# 1054  Write an explanatory essay to inform fellow ci...          1         401

# %%
# Adding a word count feature to llama dataset
llama['word_count'] = llama['generated_text'].apply(get_word_count)
llama.head(5)
# Out:
#                                       generated_text  \
# 0  Dear State Senator,\n\nI'm writting to you tod...
# 1  Uh, hi! So, like, summers are, like, awesome r...
# 2  When peoples ask for advices, they sometimes t...
# 3  I think art edukation is super impotent for ki...
# 4  I think we should totally switch to renewable ...
#
#                                       writing_prompt  generated  word_count
# 0  Write a letter to your state senator in which ...          1         291
# 1  Some schools require students to complete summ...          1         311
# 2  When people ask for advice, they sometimes tal...          1         333
# 3  Many people believe that arts education is ess...          1         308
# 4  In recent years, there has been a push towards...          1         307

# %%
# Adding a word count feature to combined dataset
combined['word_count'] = combined['text'].apply(get_word_count)
combined.head(5)
# Out:
#                                                 text  generated  \
# 0  One way we can make a positive change is by li...          1
# 1  The experimental district of Vauban in Germany...          1
# 2  The successful "Day Without Cars" event in Bog...          1
# 3  The exhaust from cars pollutes our air, and th...          1
# 4  Recently, Paris faced a severe pollution probl...          1
#
#        prompt_name      model  word_count
# 0  Car-free cities  llama_70b         365
# 1  Car-free cities  llama_70b         486
# 2  Car-free cities  llama_70b         416
# 3  Car-free cities  llama_70b         367
# 4  Car-free cities  llama_70b         466

# %%
# Combining the llama dataset and the falcon dataset into one dataframe
llama_and_falcon = pd.concat([llama,falcon],axis=0,ignore_index=True)
llama_and_falcon
# Out:
#                                          generated_text  \
# 0     Dear State Senator,\n\nI'm writting to you tod...
# 1     Uh, hi! So, like, summers are, like, awesome r...
# 2     When peoples ask for advices, they sometimes t...
# 3     I think art edukation is super impotent for ki...
# 4     I think we should totally switch to renewable ...
# ...                                                 ...
# 2222  (I am not capable of personal opinions or beli...
# 2223  In "The Challenge of Exploring Venus," the aut...
# 2224  The article "Making Mona Lisa Smile" discusses...
# 2225  As a grade 6 student, I am still learning abou...
# 2226  Passage 1:\n\nCars are one of the main ways in...
#
#                                          writing_prompt  generated  word_count
# 0     Write a letter to your state senator in which ...          1         291
# 1     Some schools require students to complete summ...          1         311
# 2     When people ask for advice, they sometimes tal...          1         333
# 3     Many people believe that arts education is ess...          1         308
# 4     In recent years, there has been a push towards...          1         307
# ...                                                 ...        ...         ...
# 2222  The role of zoos in conservation and education...          1         360
# 2223  In "The Challenge of Exploring Venus," the aut...          1         442
# 2224  In the article "Making Mona Lisa Smile," the a...          1         327
# 2225  The issue of gun control is a highly contentio...          1         313
# 2226  Write an explanatory essay to inform fellow ci...          1         401
#
# [2227 rows x 4 columns]

# %%
# Renaming the columns
llama_and_falcon.rename(columns={'generated_text':'essay','writing_prompt':'prompt','generated':'LLM_written'},inplace=True)
llama_and_falcon.head(5)
# Out:
#                                                essay  \
# 0  Dear State Senator,\n\nI'm writting to you tod...
# 1  Uh, hi! So, like, summers are, like, awesome r...
# 2  When peoples ask for advices, they sometimes t...
# 3  I think art edukation is super impotent for ki...
# 4  I think we should totally switch to renewable ...
#
#                                               prompt  LLM_written  word_count
# 0  Write a letter to your state senator in which ...            1         291
# 1  Some schools require students to complete summ...            1         311
# 2  When people ask for advice, they sometimes tal...            1         333
# 3  Many people believe that arts education is ess...            1         308
# 4  In recent years, there has been a push towards...            1         307

# %% [markdown]
# ## persuade corpus 2.0

# %%
# Getting the data
persuade_corpus = pd.read_csv('../data/persuade-corpus/persuade_2.0_human_scores_demo_id_github.csv')
persuade_corpus.head(5)
# Out:
#   essay_id_comp                                          full_text  \
# 0  423A1CA112E2  Phones\n\nModern humans today are always on th...
# 1  BC75783F96E3  This essay will explain if drivers should or s...
# 2  74C8BC7417DE  Driving while the use of cellular devices\n\nT...
# 3  A8445CABFECE  Phones & Driving\n\nDrivers should not be able...
# 4  6B4F7A0165B9  Cell Phone Operation While Driving\n\nThe abil...
#
#    holistic_essay_score  word_count         prompt_name         task  \
# 0                     3         378  Phones and driving  Independent
# 1                     4         432  Phones and driving  Independent
# 2                     2         179  Phones and driving  Independent
# 3                     3         221  Phones and driving  Independent
# 4                     4         334  Phones and driving  Independent
#
#                                           assignment source_text gender  \
# 0  Today the majority of humans own and operate c...         NaN      M
# 1  Today the majority of humans own and operate c...         NaN      M
# 2  Today the majority of humans own and operate c...         NaN      F
# 3  Today the majority of humans own and operate c...         NaN      M
# 4  Today the majority of humans own and operate c...         NaN      M
#
#    grade_level ell_status          race_ethnicity economically_disadvantaged  \
# 0          NaN        NaN  Black/African American                        NaN
# 1          NaN        NaN  Black/African American                        NaN
# 2          NaN        NaN                   White                        NaN
# 3          NaN        NaN  Black/African American                        NaN
# 4          NaN        NaN                   White                        NaN
#
#   student_disability_status
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
# Dropping the unnecessary columns
persuade_corpus.drop(['essay_id_comp','holistic_essay_score','task','source_text','gender',
                      'grade_level','ell_status','race_ethnicity','economically_disadvantaged',
                      'student_disability_status'],axis=1,inplace=True)
persuade_corpus.head(5)
# Out:
#                                            full_text  word_count  \
# 0  Phones\n\nModern humans today are always on th...         378
# 1  This essay will explain if drivers should or s...         432
# 2  Driving while the use of cellular devices\n\nT...         179
# 3  Phones & Driving\n\nDrivers should not be able...         221
# 4  Cell Phone Operation While Driving\n\nThe abil...         334
#
#           prompt_name                                         assignment
# 0  Phones and driving  Today the majority of humans own and operate c...
# 1  Phones and driving  Today the majority of humans own and operate c...
# 2  Phones and driving  Today the majority of humans own and operate c...
# 3  Phones and driving  Today the majority of humans own and operate c...
# 4  Phones and driving  Today the majority of humans own and operate c...

# %%
# Getting the prompt_name and assignment columns for the mappers
column_dict = persuade_corpus[['prompt_name','assignment']].drop_duplicates(subset='prompt_name').to_dict('records')
prompt_mapper = {}

# Iterating through the column_dict to make the prompt_mapper
for i in range(len(column_dict)):
    prompt_mapper[column_dict[i]['prompt_name']] = column_dict[i]['assignment']

# printing the prompt mapper
prompt_mapper
# Out:
# {'Phones and driving': 'Today the majority of humans own and operate cell phones on a daily basis. In essay form, explain if drivers should or should not be able to use cell phones in any capacity while operating a vehicle.',
#  'Car-free cities': 'Write an explanatory essay to inform fellow citizens about the advantages of limiting car usage. Your essay must be based on ideas and information that can be found in the passage set. Manage your time carefully so that you can read the passages; plan your response; write your response; and revise and edit your response. Be sure to use evidence from multiple sources; and avoid overly relying on one source. Your response should be in the form of a multiparagraph essay. Write your essay in the space provided.',
#  'Summer projects': 'Some schools require students to complete summer projects to assure they continue learning during their break. Should these summer projects be teacher-designed or student-designed? Take a position on this question. Support your response with reasons and specific examples.',
#  '"A Cowboy Who Rode the Waves"': "You have just read the article, 'A Cowboy Who Rode the Waves.' Luke's participation in the Seagoing Cowboys program allowed him to experience adventures and visit many unique places. Using information from the article, write an argument from Luke's point of view convincing others to participate in the Seagoing Cowboys program. Be sure to include: reasons to join the program; details from the article to support Luke's claims; an introduction, a body, and a conclusion to your essay.",
#  'Mandatory extracurricular activities': 'Your principal has decided that all students must participate in at least one extracurricular activity. For example, students could participate in sports, work on the yearbook, or serve on the student council. Do you agree or disagree with this decision? Use specific details and examples to convince others to support your position. ',
#  'Exploring Venus': 'In "The Challenge of Exploring Venus," the author suggests studying Venus is a worthy pursuit despite the dangers it presents. Using details from the article, write an essay evaluating how well the author supports this idea. Be sure to include: a claim that evaluates how well the author supports the idea that studying Venus is a worthy pursuit despite the dangers; an explanation of the evidence from the article that supports your claim; an introduction, a body, and a conclusion to your essay.',
#  'Facial action coding system': 'In the article "Making Mona Lisa Smile," the author describes how a new technology called the Facial Action Coding System enables computers to identify human emotions. Using details from the article, write an essay arguing whether the use of this technology to read the emotional expressions of students in a classroom is valuable.',
#  'The Face on Mars': "You have read the article 'Unmasking the Face on Mars.' Imagine you are a scientist at NASA discussing the Face with someone who thinks it was created by aliens. Using information in the article, write an argumentative essay to convince someone that the Face is just a natural landform.Be sure to include: claims to support your argument that the Face is a natural landform; evidence from the article to support your claims; an introduction, a body, and a conclusion to your argumentative essay.",
#  'Community service': 'Some of your friends perform community service. For example, some tutor elementary school children and others clean up litter. They think helping the community is very important. But other friends of yours think community service takes too much time away from what they need or want to do. \nYour principal is deciding whether to require all students to perform community service. \nWrite a letter to your principal in which you take a position on whether students should be required to perform community service. Support your position with examples.',
#  'Grades for extracurricular activities': "Your principal is considering changing school policy so that students may not participate in sports or other activities unless they have at least a grade B average. Many students have a grade C average. \nShe would like to hear the students' views on this possible policy change. Write a letter to your principal arguing for or against requiring at least a grade B average to participate in sports or other activities. Be sure to support your arguments with specific reasons.",
#  'Driverless cars': 'In the article “Driverless Cars are Coming,” the author presents both positive and negative aspects of driverless cars. Using details from the article, create an argument for or against the development of these cars.  Be sure to include: your position on driverless cars; appropriate details from the article that support your position; an introduction, a body, and a conclusion to your argumentative essay.',
#  'Does the electoral college work?': 'Write a letter to your state senator in which you argue in favor of keeping the Electoral College or changing to election by popular vote for the president of the United States. Use the information from the texts in your essay. Manage your time carefully so that you can read the passages; plan your response; write your response; and revise and edit your response. Be sure to include a claim; address counterclaims; use evidence from multiple sources; and avoid overly relying on one source. Your response should be in the form of a multiparagraph essay. Write your response in the space provided.',
#  'Cell phones at school': "Your principal is reconsidering the school's cell phone policy. She is considering two possible policies: \nPolicy 1: Allow students to bring phones to school and use them during lunch periods and other free times, as long as the phones are turned off during class time. \nPolicy 2: Do not allow students to have phones at school at all.\nWrite a letter to your principal convincing her which policy you believe is better. Support your position with specific reasons.",
#  'Distance learning': 'Some schools offer distance learning as an option for students to attend classes from home by way of online or video conferencing. Do you think students would benefit from being able to attend classes from home? Take a position on this issue. Support your response with reasons and examples.',
#  'Seeking multiple opinions': 'When people ask for advice, they sometimes talk to more than one person. Explain why seeking multiple opinions can help someone make a better choice. Use specific details and examples in your response.'}

# %%
# Using the mapping to add the prompt to the combined dataset
combined['prompt'] = combined['prompt_name'].map(prompt_mapper)
combined.head(5)
# Out:
#                                                 text  generated  \
# 0  One way we can make a positive change is by li...          1
# 1  The experimental district of Vauban in Germany...          1
# 2  The successful "Day Without Cars" event in Bog...          1
# 3  The exhaust from cars pollutes our air, and th...          1
# 4  Recently, Paris faced a severe pollution probl...          1
#
#        prompt_name      model  word_count  \
# 0  Car-free cities  llama_70b         365
# 1  Car-free cities  llama_70b         486
# 2  Car-free cities  llama_70b         416
# 3  Car-free cities  llama_70b         367
# 4  Car-free cities  llama_70b         466
#
#                                               prompt
# 0  Write an explanatory essay to inform fellow ci...
# 1  Write an explanatory essay to inform fellow ci...
# 2  Write an explanatory essay to inform fellow ci...
# 3  Write an explanatory essay to inform fellow ci...
# 4  Write an explanatory essay to inform fellow ci...

# %%
# Renaming and dropping columns 
combined.drop(['prompt_name','model'],axis=1,inplace=True)
combined.rename(columns={'text':'essay','generated':'LLM_written'},inplace=True)
combined.head(5)
# Out:
#                                                essay  LLM_written  word_count  \
# 0  One way we can make a positive change is by li...            1         365
# 1  The experimental district of Vauban in Germany...            1         486
# 2  The successful "Day Without Cars" event in Bog...            1         416
# 3  The exhaust from cars pollutes our air, and th...            1         367
# 4  Recently, Paris faced a severe pollution probl...            1         466
#
#                                               prompt
# 0  Write an explanatory essay to inform fellow ci...
# 1  Write an explanatory essay to inform fellow ci...
# 2  Write an explanatory essay to inform fellow ci...
# 3  Write an explanatory essay to inform fellow ci...
# 4  Write an explanatory essay to inform fellow ci...

# %%
# Concating combined with the current dataset
fully_concatenated_data = pd.concat([llama_and_falcon,combined])
fully_concatenated_data
# Out:
#                                                   essay  \
# 0     Dear State Senator,\n\nI'm writting to you tod...
# 1     Uh, hi! So, like, summers are, like, awesome r...
# 2     When peoples ask for advices, they sometimes t...
# 3     I think art edukation is super impotent for ki...
# 4     I think we should totally switch to renewable ...
# ...                                                 ...
# 6995  Driverless cars, also known as autonomous cars...
# 6996  Driverless Cars: A Necessity for Our Future\n\...
# 6997  The Pros and Cons of Driverless Cars\n\nThe wo...
# 6998  The development of driverless cars has been a ...
# 6999  Introduction\n\nThe advent of driverless cars ...
#
#                                                  prompt  LLM_written  \
# 0     Write a letter to your state senator in which ...            1
# 1     Some schools require students to complete summ...            1
# 2     When people ask for advice, they sometimes tal...            1
# 3     Many people believe that arts education is ess...            1
# 4     In recent years, there has been a push towards...            1
# ...                                                 ...          ...
# 6995  In the article “Driverless Cars are Coming,” t...            1
# 6996  In the article “Driverless Cars are Coming,” t...            1
# 6997  In the article “Driverless Cars are Coming,” t...            1
# 6998  In the article “Driverless Cars are Coming,” t...            1
# 6999  In the article “Driverless Cars are Coming,” t...            1
#
#       word_count
# 0            291
# 1            311
# 2            333
# 3            308
# 4            307
# ...          ...
# 6995         397
# 6996         405
# 6997         661
# 6998         596
# 6999         266
#
# [9227 rows x 4 columns]

# %%
# Working with the persuade corpus
persuade_corpus
# Out:
#                                                full_text  word_count  \
# 0      Phones\n\nModern humans today are always on th...         378
# 1      This essay will explain if drivers should or s...         432
# 2      Driving while the use of cellular devices\n\nT...         179
# 3      Phones & Driving\n\nDrivers should not be able...         221
# 4      Cell Phone Operation While Driving\n\nThe abil...         334
# ...                                                  ...         ...
# 25991  80% of Americans believe seeking multiple opin...        1050
# 25992  When people ask for advice,they sometimes talk...         373
# 25993  During a group project, have you ever asked a ...         631
# 25994  Making choices in life can be very difficult. ...         417
# 25995  Have you ever asked more than one person for h...         706
#
#                      prompt_name  \
# 0             Phones and driving
# 1             Phones and driving
# 2             Phones and driving
# 3             Phones and driving
# 4             Phones and driving
# ...                          ...
# 25991  Seeking multiple opinions
# 25992  Seeking multiple opinions
# 25993  Seeking multiple opinions
# 25994  Seeking multiple opinions
# 25995  Seeking multiple opinions
#
#                                               assignment
# 0      Today the majority of humans own and operate c...
# 1      Today the majority of humans own and operate c...
# 2      Today the majority of humans own and operate c...
# 3      Today the majority of humans own and operate c...
# 4      Today the majority of humans own and operate c...
# ...                                                  ...
# 25991  When people ask for advice, they sometimes tal...
# 25992  When people ask for advice, they sometimes tal...
# 25993  When people ask for advice, they sometimes tal...
# 25994  When people ask for advice, they sometimes tal...
# 25995  When people ask for advice, they sometimes tal...
#
# [25996 rows x 4 columns]

# %%
# Adding a column for generated
persuade_corpus['LLM_written'] = 0

# Dropping prompt name
persuade_corpus.drop(['prompt_name'],axis=1,inplace=True)

# Renaming columns
persuade_corpus.rename(columns={'full_text':'essay','assignment':'prompt'},inplace=True)
persuade_corpus.head(5)
# Out:
#                                                essay  word_count  \
# 0  Phones\n\nModern humans today are always on th...         378
# 1  This essay will explain if drivers should or s...         432
# 2  Driving while the use of cellular devices\n\nT...         179
# 3  Phones & Driving\n\nDrivers should not be able...         221
# 4  Cell Phone Operation While Driving\n\nThe abil...         334
#
#                                               prompt  LLM_written
# 0  Today the majority of humans own and operate c...            0
# 1  Today the majority of humans own and operate c...            0
# 2  Today the majority of humans own and operate c...            0
# 3  Today the majority of humans own and operate c...            0
# 4  Today the majority of humans own and operate c...            0

# %%
# Concatenating with the combined dataset
fully_concatenated_data = pd.concat([fully_concatenated_data,persuade_corpus])
fully_concatenated_data
# Out:
#                                                    essay  \
# 0      Dear State Senator,\n\nI'm writting to you tod...
# 1      Uh, hi! So, like, summers are, like, awesome r...
# 2      When peoples ask for advices, they sometimes t...
# 3      I think art edukation is super impotent for ki...
# 4      I think we should totally switch to renewable ...
# ...                                                  ...
# 25991  80% of Americans believe seeking multiple opin...
# 25992  When people ask for advice,they sometimes talk...
# 25993  During a group project, have you ever asked a ...
# 25994  Making choices in life can be very difficult. ...
# 25995  Have you ever asked more than one person for h...
#
#                                                   prompt  LLM_written  \
# 0      Write a letter to your state senator in which ...            1
# 1      Some schools require students to complete summ...            1
# 2      When people ask for advice, they sometimes tal...            1
# 3      Many people believe that arts education is ess...            1
# 4      In recent years, there has been a push towards...            1
# ...                                                  ...          ...
# 25991  When people ask for advice, they sometimes tal...            0
# 25992  When people ask for advice, they sometimes tal...            0
# 25993  When people ask for advice, they sometimes tal...            0
# 25994  When people ask for advice, they sometimes tal...            0
# 25995  When people ask for advice, they sometimes tal...            0
#
#        word_count
# 0             291
# 1             311
# 2             333
# 3             308
# 4             307
# ...           ...
# 25991        1050
# 25992         373
# 25993         631
# 25994         417
# 25995         706
#
# [35223 rows x 4 columns]

# %% [markdown]
# ### 1000 essays from Anthropic

# %%
anthropic = pd.read_csv('../data/persuade15_claude_instant1.csv')
anthropic.head(5)
# Out:
#    prompt_id                                        essay_title  \
# 0         14  Some schools offer distance learning as an opt...
# 1         11  In the article “Driverless Cars are Coming,” t...
# 2          8  You have read the article 'Unmasking the Face ...
# 3          6  In "The Challenge of Exploring Venus," the aut...
# 4         11  In the article “Driverless Cars are Coming,” t...
#
#                                           essay_text
# 0  While distance learning offers certain benefit...
# 1  The Development of Driverless Cars\n\nWhile dr...
# 2  While the mysterious formation known as the "F...
# 3  Studying Venus Remains a Worthy Pursuit\n\nWhi...
# 4  Driverless Cars: An Argument in Favor\n\nThe d...

# %%
# Getting the word counts
anthropic['word_count'] = anthropic['essay_text'].apply(get_word_count)
anthropic.head(5)
# Out:
#    prompt_id                                        essay_title  \
# 0         14  Some schools offer distance learning as an opt...
# 1         11  In the article “Driverless Cars are Coming,” t...
# 2          8  You have read the article 'Unmasking the Face ...
# 3          6  In "The Challenge of Exploring Venus," the aut...
# 4         11  In the article “Driverless Cars are Coming,” t...
#
#                                           essay_text  word_count
# 0  While distance learning offers certain benefit...         307
# 1  The Development of Driverless Cars\n\nWhile dr...         356
# 2  While the mysterious formation known as the "F...         318
# 3  Studying Venus Remains a Worthy Pursuit\n\nWhi...         303
# 4  Driverless Cars: An Argument in Favor\n\nThe d...         322

# %%
# Dropping columns, adding columns, and renaming columns
anthropic.drop(['prompt_id'],axis=1,inplace=True)
anthropic['LLM_written'] = 1
anthropic.rename(columns={'essay_title':'prompt','essay_text':'essay'},inplace=True)
anthropic.head(5)
# Out:
#                                               prompt  \
# 0  Some schools offer distance learning as an opt...
# 1  In the article “Driverless Cars are Coming,” t...
# 2  You have read the article 'Unmasking the Face ...
# 3  In "The Challenge of Exploring Venus," the aut...
# 4  In the article “Driverless Cars are Coming,” t...
#
#                                                essay  word_count  LLM_written
# 0  While distance learning offers certain benefit...         307            1
# 1  The Development of Driverless Cars\n\nWhile dr...         356            1
# 2  While the mysterious formation known as the "F...         318            1
# 3  Studying Venus Remains a Worthy Pursuit\n\nWhi...         303            1
# 4  Driverless Cars: An Argument in Favor\n\nThe d...         322            1

# %%
# Adding anthropic to the final dataset
fully_concatenated_data = pd.concat([fully_concatenated_data,anthropic])
fully_concatenated_data
# Out:
#                                                  essay  \
# 0    Dear State Senator,\n\nI'm writting to you tod...
# 1    Uh, hi! So, like, summers are, like, awesome r...
# 2    When peoples ask for advices, they sometimes t...
# 3    I think art edukation is super impotent for ki...
# 4    I think we should totally switch to renewable ...
# ..                                                 ...
# 995  Limiting car usage has many benefits for moder...
# 996  The Rise of Driverless Cars\n\nThe development...
# 997  Schools should allow students to design their ...
# 998  The Open Sea Beckons\n\nThe Seagoing Cowboys p...
# 999  While technology often progresses society in p...
#
#                                                 prompt  LLM_written  \
# 0    Write a letter to your state senator in which ...            1
# 1    Some schools require students to complete summ...            1
# 2    When people ask for advice, they sometimes tal...            1
# 3    Many people believe that arts education is ess...            1
# 4    In recent years, there has been a push towards...            1
# ..                                                 ...          ...
# 995  Write an explanatory essay to inform fellow ci...            1
# 996  In the article “Driverless Cars are Coming,” t...            1
# 997  Some schools require students to complete summ...            1
# 998  You have just read the article, 'A Cowboy Who ...            1
# 999  In the article “Driverless Cars are Coming,” t...            1
#
#      word_count
# 0           291
# 1           311
# 2           333
# 3           308
# 4           307
# ..          ...
# 995         349
# 996         297
# 997         303
# 998         357
# 999         359
#
# [36223 rows x 4 columns]

# %% [markdown]
# ### ArguGPT

# %%
# Importing the data
argugpt = pd.read_csv('../data/ArguGPT/argugpt.csv')
argugpt.head(5)
# Out:
#          id prompt_id                                             prompt  \
# 0  weccl_30  WECCL-17  Some people think the university education is ...
# 1  weccl_51  WECCL-17  Some people think the university education is ...
# 2  weccl_48  WECCL-17  Some people think the university education is ...
# 3  weccl_50  WECCL-17  Some people think the university education is ...
# 4  weccl_55  WECCL-17  Some people think the university education is ...
#
#                                                 text             model  \
# 0  There are many people who think that universit...  text-babbage-001
# 1  There are a number of reasons why people might...  text-babbage-001
# 2  There are many reasons why university educatio...  text-babbage-001
# 3  There are many people who think that universit...  text-babbage-001
# 4  There is a general consensus that university e...  text-babbage-001
#
#    temperature exam_type  score score_level
# 0         0.50     weccl     19        high
# 1         0.65     weccl     13      medium
# 2         0.65     weccl     13      medium
# 3         0.65     weccl     12         low
# 4         0.80     weccl     13      medium

# %%
# Getting the columns that I need
argugpt = argugpt[['prompt','text']]

# Adding the word_count and LL_written columns
argugpt['word_count'] = argugpt['text'].apply(get_word_count)
argugpt['LLM_written'] = 1

# Renaming the text column
argugpt.rename(columns={'text':'essay'},inplace=True)
argugpt.head()
# Out:
#                                               prompt  \
# 0  Some people think the university education is ...
# 1  Some people think the university education is ...
# 2  Some people think the university education is ...
# 3  Some people think the university education is ...
# 4  Some people think the university education is ...
#
#                                                essay  word_count  LLM_written
# 0  There are many people who think that universit...         324            1
# 1  There are a number of reasons why people might...         241            1
# 2  There are many reasons why university educatio...         114            1
# 3  There are many people who think that universit...         174            1
# 4  There is a general consensus that university e...         111            1

# %%
# Concatenating this data
fully_concatenated_data = pd.concat([fully_concatenated_data,argugpt])
fully_concatenated_data
# Out:
#                                                   essay  \
# 0     Dear State Senator,\n\nI'm writting to you tod...
# 1     Uh, hi! So, like, summers are, like, awesome r...
# 2     When peoples ask for advices, they sometimes t...
# 3     I think art edukation is super impotent for ki...
# 4     I think we should totally switch to renewable ...
# ...                                                 ...
# 4033  The notion that one must be forced to defend a...
# 4034  I strongly agree with the statement that menta...
# 4035  In today’s world, where competition is highly ...
# 4036  Education is one of the most powerful tools th...
# 4037  As the world is evolving rapidly, the need for...
#
#                                                  prompt  LLM_written  \
# 0     Write a letter to your state senator in which ...            1
# 1     Some schools require students to complete summ...            1
# 2     When people ask for advice, they sometimes tal...            1
# 3     Many people believe that arts education is ess...            1
# 4     In recent years, there has been a push towards...            1
# ...                                                 ...          ...
# 4033  Only by being forced to defend an idea against...            1
# 4034  Students should be encouraged to realize that ...            1
# 4035  The best preparation for life or a career is n...            1
# 4036  AII nations should help support the developmen...            1
# 4037  Colleges and universities should require all f...            1
#
#       word_count
# 0            291
# 1            311
# 2            333
# 3            308
# 4            307
# ...          ...
# 4033         568
# 4034         352
# 4035         540
# 4036         428
# 4037         380
#
# [40261 rows x 4 columns]

# %% [markdown]
# ### DAIGT | External Dataset

# %%
# Importing the data
daigt = pd.read_csv('../data/daigt_external_dataset.csv')
daigt.head(5)
# Out:
#              id                                               text  \
# 0  6060D28C05B6  Some schools in United States ofter classes fr...
# 1  60623DB5DE7A  Four-day work week, a remarkable idea to conse...
# 2  607A39D981DE  Students and their families should consider an...
# 3  60ACDFA1609E  Agree you will never grow if something beyond ...
# 4  60AE13D3F07B  I think our character traits are formed by inf...
#
#                                         instructions  \
# 0  \nTask: Write a persuasive essay on whether or...
# 1  \nTask: Research the advantages and disadvanta...
# 2  \nTask: \n\n1. Talk to your parents before tak...
# 3  \nTask: Write an essay discussing the benefits...
# 4  \nTask: Research and discuss how character tra...
#
#                                          source_text
# 0  \nWhen considering the pros and cons of attend...
# 1  \nOne of the primary arguments for implementin...
# 2  \nBefore making any decisions about getting in...
# 3  \nRalph Waldo Emerson once said, "Go confident...
# 4  \nHuman character traits are shaped by a wide ...

# %%
# In the DAIGT data, there are essays for students (text column) and essays generated by ChatGPT (source_text column)
# Splitting up the data into student and generated
student_essays = daigt[['text','instructions']].copy()
generated_essays = daigt[['source_text','instructions']].copy()

# %%
# Adding columns, renaming columns
student_essays.rename(columns={'text':'essay','instructions':'prompt'},inplace=True)
generated_essays.rename(columns={'source_text':'essay','instructions':'prompt'},inplace=True)

student_essays['word_count'] = student_essays['essay'].apply(get_word_count)
generated_essays['word_count'] = generated_essays['essay'].apply(get_word_count)

student_essays['LLM_written'] = 0
generated_essays['LLM_written'] = 1

# %%
# Concatenating
fully_concatenated_data = pd.concat([fully_concatenated_data,student_essays,generated_essays])
fully_concatenated_data
# Out:
#                                                   essay  \
# 0     Dear State Senator,\n\nI'm writting to you tod...
# 1     Uh, hi! So, like, summers are, like, awesome r...
# 2     When peoples ask for advices, they sometimes t...
# 3     I think art edukation is super impotent for ki...
# 4     I think we should totally switch to renewable ...
# ...                                                 ...
# 2416  \nBecoming a surgeon requires a great deal of ...
# 2417  \nSchools should offer an after school homewor...
# 2418  \nIt’s human nature to be afraid to make mista...
# 2419  \nOne of the main debates of 2020 for many stu...
# 2420  \nThe implementation of a curfew for teenagers...
#
#                                                  prompt  LLM_written  \
# 0     Write a letter to your state senator in which ...            1
# 1     Some schools require students to complete summ...            1
# 2     When people ask for advice, they sometimes tal...            1
# 3     Many people believe that arts education is ess...            1
# 4     In recent years, there has been a push towards...            1
# ...                                                 ...          ...
# 2416  \nTask: Research different kinds of medical pr...            1
# 2417  \nTask: Write an essay discussing why schools ...            1
# 2418  \nTask: Write an essay about how having a few ...            1
# 2419  \nTask: \n\nWrite an essay exploring the pros ...            1
# 2420  \nTask: Analyze and explore the benefits of im...            1
#
#       word_count
# 0            291
# 1            311
# 2            333
# 3            308
# 4            307
# ...          ...
# 2416         114
# 2417         297
# 2418         193
# 2419         245
# 2420         128
#
# [45103 rows x 4 columns]

# %% [markdown]
# ### LLM - Detect AI Generated Text

# %%
# Getting the data and the prompt mapper
data = pd.read_csv('../data/llm-detect-ai-generated-text/train_essays.csv')
prompts = pd.read_csv('../data/llm-detect-ai-generated-text/train_prompts.csv')
data.head()
# Out:
#          id  prompt_id                                               text  \
# 0  0059830c          0  Cars. Cars have been around since they became ...
# 1  005db917          0  Transportation is a large necessity in most co...
# 2  008f63e3          0  "America's love affair with it's vehicles seem...
# 3  00940276          0  How often do you ride in a car? Do you drive a...
# 4  00c39458          0  Cars are a wonderful thing. They are perhaps o...
#
#    generated
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
prompts.head()
# Out:
#    prompt_id                       prompt_name  \
# 0          0                   Car-free cities
# 1          1  Does the electoral college work?
#
#                                         instructions  \
# 0  Write an explanatory essay to inform fellow ci...
# 1  Write a letter to your state senator in which ...
#
#                                          source_text
# 0  # In German Suburb, Life Goes On Without Cars ...
# 1  # What Is the Electoral College? by the Office...

# %%
# Joining the 2 datasets
joined_data = data.join(other=prompts,on='prompt_id',rsuffix='_prompt')
joined_data.head()
# Out:
#          id  prompt_id                                               text  \
# 0  0059830c          0  Cars. Cars have been around since they became ...
# 1  005db917          0  Transportation is a large necessity in most co...
# 2  008f63e3          0  "America's love affair with it's vehicles seem...
# 3  00940276          0  How often do you ride in a car? Do you drive a...
# 4  00c39458          0  Cars are a wonderful thing. They are perhaps o...
#
#    generated  prompt_id_prompt      prompt_name  \
# 0          0                 0  Car-free cities
# 1          0                 0  Car-free cities
# 2          0                 0  Car-free cities
# 3          0                 0  Car-free cities
# 4          0                 0  Car-free cities
#
#                                         instructions  \
# 0  Write an explanatory essay to inform fellow ci...
# 1  Write an explanatory essay to inform fellow ci...
# 2  Write an explanatory essay to inform fellow ci...
# 3  Write an explanatory essay to inform fellow ci...
# 4  Write an explanatory essay to inform fellow ci...
#
#                                          source_text
# 0  # In German Suburb, Life Goes On Without Cars ...
# 1  # In German Suburb, Life Goes On Without Cars ...
# 2  # In German Suburb, Life Goes On Without Cars ...
# 3  # In German Suburb, Life Goes On Without Cars ...
# 4  # In German Suburb, Life Goes On Without Cars ...

# %%
# Dropping columns and renaming columns
joined_data.drop(['prompt_id','prompt_id_prompt','prompt_name','source_text','id'],axis=1,inplace=True)
joined_data.rename(columns={'text':'essay','instructions':'prompt','generated':'LLM_written'},inplace=True)
joined_data['word_count'] = joined_data['essay'].apply(get_word_count)
joined_data.head()
# Out:
#                                                essay  LLM_written  \
# 0  Cars. Cars have been around since they became ...            0
# 1  Transportation is a large necessity in most co...            0
# 2  "America's love affair with it's vehicles seem...            0
# 3  How often do you ride in a car? Do you drive a...            0
# 4  Cars are a wonderful thing. They are perhaps o...            0
#
#                                               prompt  word_count
# 0  Write an explanatory essay to inform fellow ci...         584
# 1  Write an explanatory essay to inform fellow ci...         459
# 2  Write an explanatory essay to inform fellow ci...         750
# 3  Write an explanatory essay to inform fellow ci...         698
# 4  Write an explanatory essay to inform fellow ci...         863

# %%
# Concatenating the data
fully_concatenated_data = pd.concat([fully_concatenated_data,joined_data])
fully_concatenated_data
# Out:
#                                                   essay  \
# 0     Dear State Senator,\n\nI'm writting to you tod...
# 1     Uh, hi! So, like, summers are, like, awesome r...
# 2     When peoples ask for advices, they sometimes t...
# 3     I think art edukation is super impotent for ki...
# 4     I think we should totally switch to renewable ...
# ...                                                 ...
# 1373  There has been a fuss about the Elector Colleg...
# 1374  Limiting car usage has many advantages. Such a...
# 1375  There's a new trend that has been developing f...
# 1376  As we all know cars are a big part of our soci...
# 1377  Cars have been around since the 1800's and hav...
#
#                                                  prompt  LLM_written  \
# 0     Write a letter to your state senator in which ...            1
# 1     Some schools require students to complete summ...            1
# 2     When people ask for advice, they sometimes tal...            1
# 3     Many people believe that arts education is ess...            1
# 4     In recent years, there has been a push towards...            1
# ...                                                 ...          ...
# 1373  Write a letter to your state senator in which ...            0
# 1374  Write an explanatory essay to inform fellow ci...            0
# 1375  Write an explanatory essay to inform fellow ci...            0
# 1376  Write an explanatory essay to inform fellow ci...            0
# 1377  Write an explanatory essay to inform fellow ci...            0
#
#       word_count
# 0            291
# 1            311
# 2            333
# 3            308
# 4            307
# ...          ...
# 1373         428
# 1374         398
# 1375         745
# 1376         524
# 1377         447
#
# [46481 rows x 4 columns]

# %% [markdown]
# ### LLM-generated essay using PaLM from Google Gen-AI

# %%
palm = pd.read_csv('../data/LLM_generated_essay_PaLM.csv')
palm.head()
# Out:
#    id  prompt_id                                               text  generated
# 0   0        0.0  ## The Advantages of Limiting Car Usage\n\nIn ...        1.0
# 1   1        0.0  The United States is a car-dependent nation, w...        1.0
# 2   2        0.0  In recent years, there has been a growing move...        1.0
# 3   3        0.0  In recent years, there has been a growing move...        1.0
# 4   4        0.0  In the past few decades, the United States has...        1.0

# %%
# Joining with prompts
palm = palm.join(prompts,on='prompt_id',rsuffix="_prompt")
palm.head()
# Out:
#    id  prompt_id                                               text  \
# 0   0        0.0  ## The Advantages of Limiting Car Usage\n\nIn ...
# 1   1        0.0  The United States is a car-dependent nation, w...
# 2   2        0.0  In recent years, there has been a growing move...
# 3   3        0.0  In recent years, there has been a growing move...
# 4   4        0.0  In the past few decades, the United States has...
#
#    generated  prompt_id_prompt      prompt_name  \
# 0        1.0                 0  Car-free cities
# 1        1.0                 0  Car-free cities
# 2        1.0                 0  Car-free cities
# 3        1.0                 0  Car-free cities
# 4        1.0                 0  Car-free cities
#
#                                         instructions  \
# 0  Write an explanatory essay to inform fellow ci...
# 1  Write an explanatory essay to inform fellow ci...
# 2  Write an explanatory essay to inform fellow ci...
# 3  Write an explanatory essay to inform fellow ci...
# 4  Write an explanatory essay to inform fellow ci...
#
#                                          source_text
# 0  # In German Suburb, Life Goes On Without Cars ...
# 1  # In German Suburb, Life Goes On Without Cars ...
# 2  # In German Suburb, Life Goes On Without Cars ...
# 3  # In German Suburb, Life Goes On Without Cars ...
# 4  # In German Suburb, Life Goes On Without Cars ...

# %%
# Dropping columns and renaming columns
palm.drop(['id','prompt_id','prompt_id_prompt','prompt_name','source_text'],axis=1,inplace=True)
palm.rename(columns={'text':'essay','generated':'LLM_written','instructions':'prompt'},inplace=True)
palm['word_count'] = palm['essay'].apply(get_word_count)
palm.head()
# Out:
#                                                essay  LLM_written  \
# 0  ## The Advantages of Limiting Car Usage\n\nIn ...          1.0
# 1  The United States is a car-dependent nation, w...          1.0
# 2  In recent years, there has been a growing move...          1.0
# 3  In recent years, there has been a growing move...          1.0
# 4  In the past few decades, the United States has...          1.0
#
#                                               prompt  word_count
# 0  Write an explanatory essay to inform fellow ci...         483
# 1  Write an explanatory essay to inform fellow ci...         443
# 2  Write an explanatory essay to inform fellow ci...         402
# 3  Write an explanatory essay to inform fellow ci...         448
# 4  Write an explanatory essay to inform fellow ci...         367

# %%
# Concatenating
fully_concatenated_data = pd.concat([fully_concatenated_data,palm])
fully_concatenated_data
# Out:
#                                                   essay  \
# 0     Dear State Senator,\n\nI'm writting to you tod...
# 1     Uh, hi! So, like, summers are, like, awesome r...
# 2     When peoples ask for advices, they sometimes t...
# 3     I think art edukation is super impotent for ki...
# 4     I think we should totally switch to renewable ...
# ...                                                 ...
# 1379  Dear Senator,\n\nI am writing to you today to ...
# 1380  Dear Senator,\n\nI am writing to you today to ...
# 1381  Dear Senator,\n\nI am writing to you today to ...
# 1382  Dear Senator,\n\nI am writing to you today to ...
# 1383  Dear Senator,\n\nI am writing to you today to ...
#
#                                                  prompt  LLM_written  \
# 0     Write a letter to your state senator in which ...          1.0
# 1     Some schools require students to complete summ...          1.0
# 2     When people ask for advice, they sometimes tal...          1.0
# 3     Many people believe that arts education is ess...          1.0
# 4     In recent years, there has been a push towards...          1.0
# ...                                                 ...          ...
# 1379  Write a letter to your state senator in which ...          1.0
# 1380  Write a letter to your state senator in which ...          1.0
# 1381  Write a letter to your state senator in which ...          1.0
# 1382  Write a letter to your state senator in which ...          1.0
# 1383  Write a letter to your state senator in which ...          1.0
#
#       word_count
# 0            291
# 1            311
# 2            333
# 3            308
# 4            307
# ...          ...
# 1379         374
# 1380         351
# 1381         274
# 1382         253
# 1383         399
#
# [47865 rows x 4 columns]

# %% [markdown]
# ### essays-with-instructions

# %%
data = pd.read_parquet('../data/essays-with-titles&instructions.parquet')
data.head()
# Out:
#                                         instructions  \
# 0  Write the original essay that generated the fo...
# 1  Provide the inputted essay that when summarize...
# 0  Write the original essay for the following sum...
# 1  Provide the full text for the following summar...
# 2  Provide the inputted essay that when summarize...
#
#                                               titles  \
# 0   The essay discusses the issue of whether or n...
# 1  \n\nThe organization's learning and developmen...
# 0   The author of this essay discusses how busine...
# 1  \n\n"A Darkling Plain" a Book by Kristen Monro...
# 2   A little electronic magic at Alibaba.com Case...
#
#                                               essays  \
# 0  2-6-Year-Olds’ Criminal Actions Irresponsibili...
# 1  5Ways Foodservices: Staff Learning and Develop...
# 0  10 Steps of Getting Started With Social Media ...
# 1  “A Darkling Plain” a Book by Kristen Monroe Es...
# 2  A Little Electronic Magic at Alibaba.com Case ...
#
#                                                 urls
# 0  https://ivypanda.com/essays/2-6-year-olds-crim...
# 1  https://ivypanda.com/essays/5ways-foodservices...
# 0  https://ivypanda.com/essays/10-steps-of-gettin...
# 1  https://ivypanda.com/essays/a-darkling-plain-a...
# 2  https://ivypanda.com/essays/a-little-electroni...

# %%
# Column adjustment
data.rename(columns={'instructions':'prompt','essays':'essay'},inplace=True)
data.drop(['titles','urls'],axis=1,inplace=True)
data['word_count'] = data['essay'].apply(get_word_count)
data['LLM_written'] = 0
data.head()
# Out:
#                                               prompt  \
# 0  Write the original essay that generated the fo...
# 1  Provide the inputted essay that when summarize...
# 0  Write the original essay for the following sum...
# 1  Provide the full text for the following summar...
# 2  Provide the inputted essay that when summarize...
#
#                                                essay  word_count  LLM_written
# 0  2-6-Year-Olds’ Criminal Actions Irresponsibili...         662            0
# 1  5Ways Foodservices: Staff Learning and Develop...        2123            0
# 0  10 Steps of Getting Started With Social Media ...         925            0
# 1  “A Darkling Plain” a Book by Kristen Monroe Es...        1157            0
# 2  A Little Electronic Magic at Alibaba.com Case ...         909            0

# %%
# Concatenating
fully_concatenated_data = pd.concat([fully_concatenated_data,data])
fully_concatenated_data
# Out:
#                                                 essay  \
# 0   Dear State Senator,\n\nI'm writting to you tod...
# 1   Uh, hi! So, like, summers are, like, awesome r...
# 2   When peoples ask for advices, they sometimes t...
# 3   I think art edukation is super impotent for ki...
# 4   I think we should totally switch to renewable ...
# ..                                                ...
# 24  Selected Works of Lu Hsun Research Paper\n\nFi...
# 25  Self-Understanding Role in Organizational Beha...
# 26  “Sequoia Gardens” by Ernest Finney Literature ...
# 27  Service Marketing: Food Market Essay\n\nTable ...
# 28  Sex Education in District School Curricular Es...
#
#                                                prompt  LLM_written  word_count
# 0   Write a letter to your state senator in which ...          1.0         291
# 1   Some schools require students to complete summ...          1.0         311
# 2   When people ask for advice, they sometimes tal...          1.0         333
# 3   Many people believe that arts education is ess...          1.0         308
# 4   In recent years, there has been a push towards...          1.0         307
# ..                                                ...          ...         ...
# 24  Provide the full text for the following summar...          0.0        2631
# 25  Create the inputted essay that provided the fo...          0.0        1061
# 26  Write the full essay for the following summary...          0.0        1134
# 27  Convert the following summary back into the or...          0.0         555
# 28  Provide a essay that could have been the input...          0.0         901
#
# [49929 rows x 4 columns]

# %% [markdown]
# ### Putting the Fully Concatenated DataFrame into the SQL Table

# %%
# Connecting to the database
connector_string = f'mysql+mysqlconnector://{credentials["user"]}:{credentials["password"]}@{credentials["host"]}/AuthenticAI'
engine = sqlalchemy.create_engine(connector_string,echo=True)

# Opening a connection
with engine.connect() as db_connection:
    # Pushing the dataframe to the SQL table
    fully_concatenated_data.to_sql('essays',db_connection,chunksize=10000,if_exists='append',index=False)
# Out:
# 2024-01-04 16:30:43,464 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-01-04 16:30:43,469 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-04 16:30:43,498 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-01-04 16:30:43,515 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-04 16:30:43,527 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-01-04 16:30:43,536 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-04 16:30:43,545 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-04 16:30:43,560 INFO sqlalchemy.engine.Engine DESCRIBE `authenticai`.`essays`
# 2024-01-04 16:30:43,564 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-04 16:30:43,782 INFO sqlalchemy.engine.Engine INSERT INTO essays (essay, prompt, `LLM_written`, word_count) VALUES (%(essay)s, %(prompt)s, %(LLM_written)s, %(word_count)s)
# 2024-01-04 16:30:43,783 INFO sqlalchemy.engine.Engine [generated in 0.12136s] [{'essay': "Dear State Senator,\n\nI'm writting to you today to tell you that we should keep the Electoral College. I know some people say it's unfair but I thin ... (1271 characters truncated) ... them.\n\nSo, I think we should keep the Electoral College. It's a good system that helps make sure the president is fair to everyone.\n\nSincerely,\n", 'prompt': 'Write a letter to your state senator in which you argue in favor of keeping the Electoral College or changing to election by popular vote for the pre ... (300 characters truncated) ... es; and avoid overly relying on one source. Your response should be in the form of a multiparagraph essay. Write your response in the space provided.', 'LLM_written': 1.0, 'word_count': 291}, {'essay': "Uh, hi! So, like, summers are, like, awesome right? We get, like, no school and we can, like, play outside n stuff. But, like, some schools make us d ... (1340 characters truncated) ... 're, like, super effective. So, like, let's all, like, do student-designed projects and, like, have a blast doing it! Thanks for, like, reading this!", 'prompt': 'Some schools require students to complete summer projects to assure they continue learning during their break. Should these summer projects be teacher-designed or student-designed? Take a position on this question. Support your response with reasons and specific examples.', 'LLM_written': 1.0, 'word_count': 311}, {'essay': "When peoples ask for advices, they sometimes talk to more than one person. This is a good thing to do because it can help them make a better choise.\ ... (1528 characters truncated) ... because it gives you different perspectives and helps you avoid bias. So, the next time you need advice, don't be afraid to ask more than one person!", 'prompt': 'When people ask for advice, they sometimes talk to more than one person. Explain why seeking multiple opinions can help someone make a better choice. Use specific details and examples in your response.', 'LLM_written': 1.0, 'word_count': 333}, {'essay': 'I think art edukation is super impotent for kids. Some peoples might say its not that impotent but I disagree. Arts helps kids with theyre imaginatio ... (1361 characters truncated) ... r selfs. It also helps us develop our brain and be more creative. Art should be a requirement in skool cuz its impotent for a well-rounded edukation.', 'prompt': 'Many people believe that arts education is essential for a well-rounded education, while others think that it should be optional. Take a position on this issue, providing specific reasons and examples to support your argument.', 'LLM_written': 1.0, 'word_count': 308}, {'essay': "I think we should totally switch to renewable energy! Fossil fuels are bad for the earth and renewable energy is good. First of all, fossil fuels are ... (1352 characters truncated) ... for our planet, our health, and our future. We should invest in renewable energy now and make the world a better place for us and future generations.", 'prompt': 'In recent years, there has been a push towards using renewable energy sources. Argue for or against the transition from fossil fuels to renewable energy, providing reasons and examples to support your position.', 'LLM_written': 1.0, 'word_count': 307}, {'essay': "I think that it's a good idea for us to have to participate in an extracurricular activity. I know some people might think it's dumb but I think it's ... (739 characters truncated) ... at we're well-rounded and involved in our school. So, I think we should all just suck it up and do an extracurricular activity. It might even be fun!", 'prompt': 'Your principal has decided that all students must participate in at least one extracurricular activity. For example, students could participate in sp ... (36 characters truncated) ...  on the student council. Do you agree or disagree with this decision? Use specific details and examples to convince othe ...
# 2024-01-04 16:30:47,645 INFO sqlalchemy.engine.Engine INSERT INTO essays (essay, prompt, `LLM_written`, word_count) VALUES (%(essay)s, %(prompt)s, %(LLM_written)s, %(word_count)s)
# 2024-01-04 16:30:47,646 INFO sqlalchemy.engine.Engine [cached since 3.984s ago] [{'essay': "Phones and Driving\n\nAlmost everyone in the world owns a cell phone of some kind. We use them to communicate with others, go on the internet, access ... (2260 characters truncated) ... driving, your main focus should be on the road. Your safety should matter more than whatever message, call, or notification you get on your phone.   ", 'prompt': 'Today the majority of humans own and operate cell phones on a daily basis. In essay form, explain if drivers should or should not be able to use cell phones in any capacity while operating a vehicle.', 'LLM_written': 0.0, 'word_count': 452}, {'essay': "Phones and Driving\n\nPhones are everywhere in today's society with all different versions of a phone but the biggest problem is using your phone whi ... (2346 characters truncated) ... fe driving down the road. It is our responsibility to keep our friends and family safe on the road and anywhere we go.                               ", 'prompt': 'Today the majority of humans own and operate cell phones on a daily basis. In essay form, explain if drivers should or should not be able to use cell phones in any capacity while operating a vehicle.', 'LLM_written': 0.0, 'word_count': 514}, {'essay': "Phones and Driving\n\nDanger has fascinated humans for centuries. So has technological advancements or just technology in general. Cell phones are a  ... (1936 characters truncated) ... 's urgency of safety while driving should too. What's more important, what Kim Kardashian just did on Snapchat, or your life and everyone else's?    ", 'prompt': 'Today the majority of humans own and operate cell phones on a daily basis. In essay form, explain if drivers should or should not be able to use cell phones in any capacity while operating a vehicle.', 'LLM_written': 0.0, 'word_count': 383}, {'essay': 'Cell Phones Are Killers\n\nThe future brings many new advances in technology, and along with it, dangers and responsibilities. Cell phones are highly ... (2394 characters truncated) ... cil.\n\nAndrew. currin. ctr@dot. gov. "U Drive. U text. U pay." NHTSA, 8 May 2019, https://www. nhtsa. gov/risky-driving/distracted-driving.         ', 'prompt': 'Today the majority of humans own and operate cell phones on a daily basis. In essay form, explain if drivers should or should not be able to use cell phones in any capacity while operating a vehicle.', 'LLM_written': 0.0, 'word_count': 407}, {'essay': 'Cell Phones are now seen as an essential item for millions of people. Throughout each day people need to use their phones for multiple reasons includ ... (6166 characters truncated) ... usage close to none, use them to keep yourself safe. So, next time your phone rings, make sure to send the right message by not sending that text.   ', 'prompt': 'Today the majority of humans own and operate cell phones on a daily basis. In essay form, explain if drivers should or should not be able to use cell phones in any capacity while operating a vehicle.', 'LLM_written': 0.0, 'word_count': 1152}, {'essay': "Phones & Driving\n\nNow in the 21st century, the major of humans own and use cell phones daily. The number of teens who are dying or being injured as ... (1925 characters truncated) ...  bigger and bigger and while the death rate would keep on increasing as time goes until everyone fix the texting while driving problems continues.   ", 'prompt': 'Today the majority of humans own and operate cell phones on a daily basis. In essay form, explain if drivers should or should not be able to use cell phones in any capacity while operating a vehicle.', 'LLM_written': 0.0, 'word_count': 370}, {'essay': "Phones & Driving\n\nOver the years, phones have developed to be an important thing in our life. Phones are apart of our everyday lives and sometimes  ... (2289 characters truncated) ... u but to others also. Always remember that everybody's life is important including yours. So the text/call ca ...
# 2024-01-04 16:30:50,946 INFO sqlalchemy.engine.Engine INSERT INTO essays (essay, prompt, `LLM_written`, word_count) VALUES (%(essay)s, %(prompt)s, %(LLM_written)s, %(word_count)s)
# 2024-01-04 16:30:50,948 INFO sqlalchemy.engine.Engine [cached since 7.286s ago] [{'essay': 'Nowadays people show their emotions simply just by looking at their face. Today\'s technology is advancing quickly that they even found a way to tell ... (1647 characters truncated) ...  reproduce smiling and frowining as a way of creating these emotions on stage. Someone\'s emtions is way more different than the science of emotions.', 'prompt': 'In the article "Making Mona Lisa Smile," the author describes how a new technology called the Facial Action Coding System enables computers to identi ... (33 characters truncated) ... from the article, write an essay arguing whether the use of this technology to read the emotional expressions of students in a classroom is valuable.', 'LLM_written': 0.0, 'word_count': 314}, {'essay': 'Imangine being able to know the emotions of students during class, such as when they are bored, or when they are confused. Thats what the new Facial  ... (1954 characters truncated) ... people assuem tht sudents do bad in school becuase they dont pay attention, but thsi is usualy becuase the lessons are either confusing or boring.   ', 'prompt': 'In the article "Making Mona Lisa Smile," the author describes how a new technology called the Facial Action Coding System enables computers to identi ... (33 characters truncated) ... from the article, write an essay arguing whether the use of this technology to read the emotional expressions of students in a classroom is valuable.', 'LLM_written': 0.0, 'word_count': 373}, {'essay': 'I think the technology called the Facial Action Coding System is valuable because I think it is a very big advantage of using this type of technology ... (726 characters truncated) ... d agree with it, I think many people would love to have a less stressful job, Sometimes it can get stressful in thinking what to do for the painting.', 'prompt': 'In the article "Making Mona Lisa Smile," the author describes how a new technology called the Facial Action Coding System enables computers to identi ... (33 characters truncated) ... from the article, write an essay arguing whether the use of this technology to read the emotional expressions of students in a classroom is valuable.', 'LLM_written': 0.0, 'word_count': 183}, {'essay': "I think the Facial Action Coding System can bring some help into classrooms. Most students, like myself, get bored when working on the computer. If t ... (1089 characters truncated) ... e. If it all goes well then it just might make school a place where children and young adults would actually look forward to going to.               ", 'prompt': 'In the article "Making Mona Lisa Smile," the author describes how a new technology called the Facial Action Coding System enables computers to identi ... (33 characters truncated) ... from the article, write an essay arguing whether the use of this technology to read the emotional expressions of students in a classroom is valuable.', 'LLM_written': 0.0, 'word_count': 261}, {'essay': 'How can a facial action coding system can identify a persons initial facial exspretion? Well what it does and how it can be helpful, useful and then  ... (1153 characters truncated) ... as mad to tell if a person was a killer or not. So in conclusion I think it is very useful in my opinon and I hope they make more of these inventions', 'prompt': 'In the article "Making Mona Lisa Smile," the author describes how a new technology called the Facial Action Coding System enables computers to identi ... (33 characters truncated) ... from the article, write an essay arguing whether the use of this technology to read the emotional expressions of students in a classroom is valuable.', 'LLM_written': 0.0, 'word_count': 281}, {'essay': 'Use of the Facial Action Coding Sysytem can be very valuable for computer learning in the class room. This system can detect emotional expressions of ... (3096 characters truncated) ... many unethical things, the Facial Action Co ...
# 2024-01-04 16:30:53,669 INFO sqlalchemy.engine.Engine INSERT INTO essays (essay, prompt, `LLM_written`, word_count) VALUES (%(essay)s, %(prompt)s, %(LLM_written)s, %(word_count)s)
# 2024-01-04 16:30:53,671 INFO sqlalchemy.engine.Engine [cached since 10.01s ago] [{'essay': "Dear Principal,\n\nI think that you should allow cell phones in school because they can be very useful. During free time cell phones can be used to c ... (859 characters truncated) ... ts for a ride home or to stay at their friends home to study. Cell phone can be a very useful tool if used properly.\n\nYour's Truly,\n\nSTUDENT_NAME", 'prompt': "Your principal is reconsidering the school's cell phone policy. She is considering two possible policies: \nPolicy 1: Allow students to bring phones  ... (169 characters truncated) ... s at school at all.\nWrite a letter to your principal convincing her which policy you believe is better. Support your position with specific reasons.", 'LLM_written': 0.0, 'word_count': 200}, {'essay': "To allow cell phones in school is like letting kids play games and school is not fun and games. One reason why cell phones should not be aloud in sch ... (670 characters truncated) ... ng class all you can think about is getting out of class to text your friend. I totally think letting kids bring cell phones to school is a bad idea.", 'prompt': "Your principal is reconsidering the school's cell phone policy. She is considering two possible policies: \nPolicy 1: Allow students to bring phones  ... (169 characters truncated) ... s at school at all.\nWrite a letter to your principal convincing her which policy you believe is better. Support your position with specific reasons.", 'LLM_written': 0.0, 'word_count': 184}, {'essay': "I think that students shouldn't be able to have a cell phone in school to use during lunch other free times for a couple reasons. Its not useful, stu ... (2044 characters truncated) ... e.\n\nAs you can see there are good reasons why phones in school is a bad idea, they can cheat, its not at all useful and it can be very distracting.", 'prompt': "Your principal is reconsidering the school's cell phone policy. She is considering two possible policies: \nPolicy 1: Allow students to bring phones  ... (169 characters truncated) ... s at school at all.\nWrite a letter to your principal convincing her which policy you believe is better. Support your position with specific reasons.", 'LLM_written': 0.0, 'word_count': 445}, {'essay': 'Dear Principal,\n\nI highly encourage you to set the policy number 1 where you allow students to bring cell phones to school. I believe cell phones a ... (2023 characters truncated) ...  other policy which can upset students and decrease their production rate. This opportunity is golden and all we need is for you to put it in affect.', 'prompt': "Your principal is reconsidering the school's cell phone policy. She is considering two possible policies: \nPolicy 1: Allow students to bring phones  ... (169 characters truncated) ... s at school at all.\nWrite a letter to your principal convincing her which policy you believe is better. Support your position with specific reasons.", 'LLM_written': 0.0, 'word_count': 408}, {'essay': "Dear principal,\n\nPolicy 2 is probably better because students text too much. Texting makes students dumber because they use short hand and spell th ... (1283 characters truncated) ... e hooked to their phone. Some kids rely on their phone too much and cannot put it down. So policy 2 is probably better.\n\nSincerely,\n\nSTUDENT_NAME", 'prompt': "Your principal is reconsidering the school's cell phone policy. She is considering two possible policies: \nPolicy 1: Allow students to bring phones  ... (169 characters truncated) ... s at school at all.\nWrite a letter to your principal convincing her which policy you believe is better. Support your position with specific reasons.", 'LLM_written': 0.0, 'word_count': 275}, {'essay': "We should be allowed to have cell phones at school during the free periods. We should get to have them when ever we like and we should be allowed to  ... (939 characters truncated) ... t after school is out and sometimes peop ...
# 2024-01-04 16:30:56,495 INFO sqlalchemy.engine.Engine INSERT INTO essays (essay, prompt, `LLM_written`, word_count) VALUES (%(essay)s, %(prompt)s, %(LLM_written)s, %(word_count)s)
# 2024-01-04 16:30:56,497 INFO sqlalchemy.engine.Engine [cached since 12.83s ago] [{'essay': "Nowadays, under the new marketing system, people have paid more and more attention to degree certificates.\n\nWhat is the difference between a bachel ... (1758 characters truncated) ... r the core part. It is important to note, however, that a student's choice of courses does not necessarily affect his or her chances of obtaining\n\n", 'prompt': "Nowadays, people have paid more and more attention to degree certificates. For example, in many institutions, one's promotion is primarily decided by ... (247 characters truncated) ... ntial for successful career. Do you agree or disagree? Use specific reasons and examples to support your answer. Write an essay of roughly 300 words.", 'LLM_written': 1.0, 'word_count': 343}, {'essay': 'There are a number of reasons why college graduates earn higher salaries than the less well-educated in the community. First, college graduates have  ... (514 characters truncated) ... the less well-educated. This allows them to pay for their education more fully, which gives them a better chance of achieving their career goals.\n\n', 'prompt': 'It is right that college graduates earn higher salaries than the less well-educated in the community. But they should also pay the full cost of their study. Do you agree or disagree? Use specific reasons and examples to support your answer. Write an essay of roughly 300 words.', 'LLM_written': 1.0, 'word_count': 133}, {'essay': 'I agree that college graduates should pay the full cost of their education. This is because, on average, college graduates earn more than the less we ... (737 characters truncated) ... n demand. For example, a college graduate is more likely to be a doctor or a computer scientist than a person who only has a high school diploma.\n\n', 'prompt': 'It is right that college graduates earn higher salaries than the less well-educated in the community. But they should also pay the full cost of their study. Do you agree or disagree? Use specific reasons and examples to support your answer. Write an essay of roughly 300 words.', 'LLM_written': 1.0, 'word_count': 183}, {'essay': "I agree that college graduates should pay the full cost of their study. College education is an investment in one’s future, and it is only fair that  ... (1429 characters truncated) ... e, it is not fair to expect taxpayers to foot the bill for someone else’s education, and paying for one’s own education can be a great motivator.\n\n", 'prompt': 'It is right that college graduates earn higher salaries than the less well-educated in the community. But they should also pay the full cost of their study. Do you agree or disagree? Use specific reasons and examples to support your answer. Write an essay of roughly 300 words.', 'LLM_written': 1.0, 'word_count': 294}, {'essay': "As the cost of higher education continues to rise, the debate over who should bear the burden of paying for it has become increasingly contentious. S ... (1888 characters truncated) ...  that extend beyond the individual, and it is the responsibility of society as a whole to invest in the education and potential of it's citizens.\n\n", 'prompt': 'It is right that college graduates earn higher salaries than the less well-educated in the community. But they should also pay the full cost of their study. Do you agree or disagree? Use specific reasons and examples to support your answer. Write an essay of roughly 300 words.', 'LLM_written': 1.0, 'word_count': 350}, {'essay': "From where I stand, the people who are well-educated don't mean they have strong ability. They mean that they know what they want to do with their li ... (60 characters truncated) ... ou are a college graduate, you should be able to afford to go to college. If you can't afford college, then you shouldn't be allowed to graduate.\n\n", 'prompt': 'It is right that college graduates earn higher salaries than the less well-educated in the community. But  ...
# 2024-01-04 16:31:01,252 INFO sqlalchemy.engine.Engine COMMIT
