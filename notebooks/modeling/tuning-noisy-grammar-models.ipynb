# %% [markdown]
# # Tuning Noisy Grammar Models
#
# I added noise to the grammar errors and trained models on it. I found the random forest and gradient model overfit to the training set and the ANN maintained performance. When I submitted the ANN to competition to test it on the test data, I found performance of the ANN on the test set to rise. Thus, I have reasonable evidence to claim that adding the noise to the grammar errors improves model performance.
#
# In this notebook, I will tune the models using Randomized Search.

# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from catboost import CatBoostClassifier
import pickle

# %matplotlib inline

# %%
# Getting the data
training_data = pd.read_csv('../../data/train-noisy-grammar.csv')
valid_data = pd.read_csv('../../data/validation.csv')

# %%
# Getting the scalar and scaling
with open('../../models/custom-features/noisy-grammar-errors/scalar-noisy.pkl','rb') as file:
    scalar = pickle.load(file)

# %%
# Getting the X and y
X_train = training_data.drop(['LLM_written','prompt','essay','row_id'],axis=1)
y_train = training_data['LLM_written'].values

X_valid = valid_data.drop(['LLM_written','prompt','essay','row_id'],axis=1)
y_valid = valid_data['LLM_written'].values

# %%
numerical = ['word_count','stop_word_count','stop_word_ratio','unique_word_count','unique_word_ratio',
             'count_question','count_exclamation','count_semi','count_colon','grammar_errors']
X_train[numerical] = scalar.transform(X_train[numerical])
X_valid[numerical] = scalar.transform(X_valid[numerical])

# %%
# Creating a dictionary for the model performances
performances = {
    'model':[],
    'Train ROC AUC':[],
    'Valid ROC AUC':[]
}

# %% [markdown]
# ## Random Forest

# %%
forest_clf = RandomForestClassifier(criterion='gini',class_weight='balanced',bootstrap=True,random_state=42,n_jobs=-1)
param_dict = {
    'n_estimators':[100,500,750],
    'max_depth':[2,3,5],
    'min_samples_leaf':[2,6,8],
    'max_features':['sqrt','log2',None],
    'max_samples':[0.3,0.5,1.0]
}

# %%
# Running the randomized search and finding the best model
search_obj = RandomizedSearchCV(forest_clf,param_dict,n_iter=20,scoring='roc_auc',refit=True,cv=3,random_state=42,return_train_score=True,
                                verbose=10,error_score="raise",n_jobs=-1)

# %%
search_obj.fit(X_train.values,y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV 1/3; 1/20] START max_depth=2, max_features=sqrt, max_samples=1.0, min_samples_leaf=8, n_estimators=100
# [CV 2/3; 1/20] START max_depth=2, max_features=sqrt, max_samples=1.0, min_samples_leaf=8, n_estimators=100
# [CV 3/3; 1/20] START max_depth=2, max_features=sqrt, max_samples=1.0, min_samples_leaf=8, n_estimators=100
# [CV 1/3; 2/20] START max_depth=2, max_features=sqrt, max_samples=0.3, min_samples_leaf=8, n_estimators=100
# [CV 1/3; 2/20] END max_depth=2, max_features=sqrt, max_samples=0.3, min_samples_leaf=8, n_estimators=100;, score=(train=0.988, test=0.942) total time=   3.5s
# [CV 2/3; 2/20] START max_depth=2, max_features=sqrt, max_samples=0.3, min_samples_leaf=8, n_estimators=100
# [CV 1/3; 1/20] END max_depth=2, max_features=sqrt, max_samples=1.0, min_samples_leaf=8, n_estimators=100;, score=(train=0.987, test=0.941) total time=   6.5s
# [CV 3/3; 2/20] START max_depth=2, max_features=sqrt, max_samples=0.3, min_samples_leaf=8, n_estimators=100
# [CV 3/3; 1/20] END max_depth=2, max_features=sqrt, max_samples=1.0, min_samples_leaf=8, n_estimators=100;, score=(train=0.976, test=0.953) total time=   7.2s
# [CV 2/3; 1/20] END max_depth=2, max_features=sqrt, max_samples=1.0, min_samples_leaf=8, n_estimators=100;, score=(train=0.981, test=0.857) total time=   7.2s
# [CV 1/3; 3/20] START max_depth=3, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=750
# [CV 2/3; 3/20] START max_depth=3, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=750
# [CV 2/3; 2/20] END max_depth=2, max_features=sqrt, max_samples=0.3, min_samples_leaf=8, n_estimators=100;, score=(train=0.982, test=0.872) total time=   4.0s
# [CV 3/3; 3/20] START max_depth=3, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=750
# [CV 3/3; 2/20] END max_depth=2, max_features=sqrt, max_samples=0.3, min_samples_leaf=8, n_estimators=100;, score=(train=0.976, test=0.953) total time=   3.6s
# [CV 1/3; 4/20] START max_depth=5, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=500
# [CV 1/3; 3/20] END max_depth=3, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=750;, score=(train=0.969, test=0.905) total time= 7.9min
# [CV 2/3; 4/20] START max_depth=5, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=500
# [CV 3/3; 3/20] END max_depth=3, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=750;, score=(train=0.968, test=0.956) total time= 8.0min
# [CV 3/3; 4/20] START max_depth=5, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=500
# [CV 2/3; 3/20] END max_depth=3, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=750;, score=(train=0.977, test=0.760) total time= 8.1min
# [CV 1/3; 5/20] START max_depth=5, max_features=None, max_samples=1.0, min_samples_leaf=6, n_estimators=500
# [CV 1/3; 4/20] END max_depth=5, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=500;, score=(train=0.988, test=0.912) total time= 8.3min
# [CV 2/3; 5/20] START max_depth=5, max_features=None, max_samples=1.0, min_samples_leaf=6, n_estimators=500
# [CV 2/3; 4/20] END max_depth=5, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=500;, score=(train=0.987, test=0.851) total time= 8.6min
# [CV 3/3; 5/20] START max_depth=5, max_features=None, max_samples=1.0, min_samples_leaf=6, n_estimators=500
# [CV 3/3; 4/20] END max_depth=5, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=500;, score=(train=0.983, test=0.963) total time= 8.5min
# [CV 1/3; 6/20] START max_depth=5, max_features=sqrt, max_samples=0.5, min_samples_leaf=6, n_estimators=500
# [CV 1/3; 6/20] END max_depth=5, max_features=sqrt, max_samples=0.5, min_samples_leaf=6, n_estimators=500;, score=(train=0.994, test=0.939) total time=  33.4s
# [CV 2/3; 6/20] START max_depth=5, max_features=sqrt, max_samples=0.5, min_samples_leaf=6, n_estimators=500
# [CV 2/3; 6/20] END max_depth=5, max_features=sqrt, max_samples=0.5, min_samples_leaf=6, n_estimators=500;, score=(train=0.990, test=0.864) total time=  34.3s
# [CV 3/3; 6/20] START max_depth=5, max_features=sqrt, max_samples=0.5, min_samples_leaf=6, n_estimators=500
# [CV 3/3; 6/20] END max_depth=5, max_features=sqrt, max_samples=0.5, min_samples_leaf=6, n_estimators=500;, score=(train=0.987, test=0.983) total time=  34.7s
# [CV 1/3; 7/20] START max_depth=5, max_features=log2, max_samples=1.0, min_samples_leaf=8, n_estimators=750
# [CV 1/3; 7/20] END max_depth=5, max_features=log2, max_samples=1.0, min_samples_leaf=8, n_estimators=750;, score=(train=0.994, test=0.921) total time=  39.4s
# [CV 2/3; 7/20] START max_depth=5, max_features=log2, max_samples=1.0, min_samples_leaf=8, n_estimators=750
# [CV 2/3; 7/20] END max_depth=5, max_features=log2, max_samples=1.0, min_samples_leaf=8, n_estimators=750;, score=(train=0.989, test=0.858) total time=  40.1s
# [CV 3/3; 7/20] START max_depth=5, max_features=log2, max_samples=1.0, min_samples_leaf=8, n_estimators=750
# [CV 3/3; 7/20] END max_depth=5, max_features=log2, max_samples=1.0, min_samples_leaf=8, n_estimators=750;, score=(train=0.985, test=0.967) total time=  42.3s
# [CV 1/3; 8/20] START max_depth=3, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=100
# [CV 1/3; 8/20] END max_depth=3, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=100;, score=(train=0.968, test=0.905) total time= 1.1min
# [CV 2/3; 8/20] START max_depth=3, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=100
# [CV 1/3; 5/20] END max_depth=5, max_features=None, max_samples=1.0, min_samples_leaf=6, n_estimators=500;, score=(train=0.987, test=0.901) total time=13.8min
# [CV 3/3; 8/20] START max_depth=3, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=100
# [CV 2/3; 5/20] END max_depth=5, max_features=None, max_samples=1.0, min_samples_leaf=6, n_estimators=500;, score=(train=0.986, test=0.849) total time=14.1min
# [CV 1/3; 9/20] START max_depth=2, max_features=sqrt, max_samples=0.5, min_samples_leaf=2, n_estimators=100
# [CV 1/3; 9/20] END max_depth=2, max_features=sqrt, max_samples=0.5, min_samples_leaf=2, n_estimators=100;, score=(train=0.988, test=0.936) total time=   5.3s
# [CV 2/3; 9/20] START max_depth=2, max_features=sqrt, max_samples=0.5, min_samples_leaf=2, n_estimators=100
# [CV 2/3; 9/20] END max_depth=2, max_features=sqrt, max_samples=0.5, min_samples_leaf=2, n_estimators=100;, score=(train=0.980, test=0.861) total time=   5.0s
# [CV 3/3; 9/20] START max_depth=2, max_features=sqrt, max_samples=0.5, min_samples_leaf=2, n_estimators=100
# [CV 3/3; 9/20] END max_depth=2, max_features=sqrt, max_samples=0.5, min_samples_leaf=2, n_estimators=100;, score=(train=0.976, test=0.955) total time=   5.3s
# [CV 1/3; 10/20] START max_depth=3, max_features=log2, max_samples=0.3, min_samples_leaf=6, n_estimators=750
# [CV 2/3; 8/20] END max_depth=3, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=100;, score=(train=0.976, test=0.770) total time= 1.1min
# [CV 2/3; 10/20] START max_depth=3, max_features=log2, max_samples=0.3, min_samples_leaf=6, n_estimators=750
# [CV 3/3; 8/20] END max_depth=3, max_features=None, max_samples=0.5, min_samples_leaf=8, n_estimators=100;, score=(train=0.967, test=0.954) total time= 1.1min
# [CV 3/3; 10/20] START max_depth=3, max_features=log2, max_samples=0.3, min_samples_leaf=6, n_estimators=750
# [CV 1/3; 10/20] END max_depth=3, max_features=log2, max_samples=0.3, min_samples_leaf=6, n_estimators=750;, score=(train=0.993, test=0.927) total time=  17.3s
# [CV 1/3; 11/20] START max_depth=2, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=100
# [CV 1/3; 11/20] END max_depth=2, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=100;, score=(train=0.988, test=0.921) total time=   4.3s
# [CV 2/3; 11/20] START max_depth=2, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=100
# [CV 2/3; 10/20] END max_depth=3, max_features=log2, max_samples=0.3, min_samples_leaf=6, n_estimators=750;, score=(train=0.987, test=0.846) total time=  15.9s
# [CV 3/3; 11/20] START max_depth=2, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=100
# [CV 2/3; 11/20] END max_depth=2, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=100;, score=(train=0.984, test=0.844) total time=   3.8s
# [CV 1/3; 12/20] START max_depth=5, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=750
# [CV 3/3; 11/20] END max_depth=2, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=100;, score=(train=0.972, test=0.896) total time=   3.6s
# [CV 2/3; 12/20] START max_depth=5, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=750
# [CV 3/3; 10/20] END max_depth=3, max_features=log2, max_samples=0.3, min_samples_leaf=6, n_estimators=750;, score=(train=0.982, test=0.949) total time=  16.3s
# [CV 3/3; 12/20] START max_depth=5, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=750
# [CV 1/3; 12/20] END max_depth=5, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=750;, score=(train=0.994, test=0.913) total time=  37.6s
# [CV 1/3; 13/20] START max_depth=5, max_features=None, max_samples=0.5, min_samples_leaf=2, n_estimators=750
# [CV 2/3; 12/20] END max_depth=5, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=750;, score=(train=0.990, test=0.858) total time=  37.4s
# [CV 2/3; 13/20] START max_depth=5, max_features=None, max_samples=0.5, min_samples_leaf=2, n_estimators=750
# [CV 3/3; 12/20] END max_depth=5, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=750;, score=(train=0.985, test=0.967) total time=  39.8s
# [CV 3/3; 13/20] START max_depth=5, max_features=None, max_samples=0.5, min_samples_leaf=2, n_estimators=750
# [CV 3/3; 5/20] END max_depth=5, max_features=None, max_samples=1.0, min_samples_leaf=6, n_estimators=500;, score=(train=0.982, test=0.963) total time=13.4min
# [CV 1/3; 14/20] START max_depth=5, max_features=sqrt, max_samples=0.3, min_samples_leaf=8, n_estimators=750
# [CV 1/3; 14/20] END max_depth=5, max_features=sqrt, max_samples=0.3, min_samples_leaf=8, n_estimators=750;, score=(train=0.994, test=0.944) total time=  34.4s
# [CV 2/3; 14/20] START max_depth=5, max_features=sqrt, max_samples=0.3, min_samples_leaf=8, n_estimators=750
# [CV 2/3; 14/20] END max_depth=5, max_features=sqrt, max_samples=0.3, min_samples_leaf=8, n_estimators=750;, score=(train=0.990, test=0.865) total time=  34.0s
# [CV 3/3; 14/20] START max_depth=5, max_features=sqrt, max_samples=0.3, min_samples_leaf=8, n_estimators=750
# [CV 3/3; 14/20] END max_depth=5, max_features=sqrt, max_samples=0.3, min_samples_leaf=8, n_estimators=750;, score=(train=0.988, test=0.983) total time=  35.0s
# [CV 1/3; 15/20] START max_depth=3, max_features=sqrt, max_samples=0.3, min_samples_leaf=2, n_estimators=500
# [CV 1/3; 15/20] END max_depth=3, max_features=sqrt, max_samples=0.3, min_samples_leaf=2, n_estimators=500;, score=(train=0.992, test=0.948) total time=  19.1s
# [CV 2/3; 15/20] START max_depth=3, max_features=sqrt, max_samples=0.3, min_samples_leaf=2, n_estimators=500
# [CV 2/3; 15/20] END max_depth=3, max_features=sqrt, max_samples=0.3, min_samples_leaf=2, n_estimators=500;, score=(train=0.988, test=0.859) total time=  18.1s
# [CV 3/3; 15/20] START max_depth=3, max_features=sqrt, max_samples=0.3, min_samples_leaf=2, n_estimators=500
# [CV 3/3; 15/20] END max_depth=3, max_features=sqrt, max_samples=0.3, min_samples_leaf=2, n_estimators=500;, score=(train=0.985, test=0.974) total time=  17.6s
# [CV 1/3; 16/20] START max_depth=3, max_features=None, max_samples=1.0, min_samples_leaf=8, n_estimators=750
# [CV 1/3; 13/20] END max_depth=5, max_features=None, max_samples=0.5, min_samples_leaf=2, n_estimators=750;, score=(train=0.988, test=0.905) total time=11.9min
# [CV 2/3; 16/20] START max_depth=3, max_features=None, max_samples=1.0, min_samples_leaf=8, n_estimators=750
# [CV 3/3; 13/20] END max_depth=5, max_features=None, max_samples=0.5, min_samples_leaf=2, n_estimators=750;, score=(train=0.984, test=0.964) total time=12.0min
# [CV 3/3; 16/20] START max_depth=3, max_features=None, max_samples=1.0, min_samples_leaf=8, n_estimators=750
# [CV 2/3; 13/20] END max_depth=5, max_features=None, max_samples=0.5, min_samples_leaf=2, n_estimators=750;, score=(train=0.987, test=0.851) total time=12.1min
# [CV 1/3; 17/20] START max_depth=5, max_features=None, max_samples=1.0, min_samples_leaf=2, n_estimators=750
# [CV 1/3; 16/20] END max_depth=3, max_features=None, max_samples=1.0, min_samples_leaf=8, n_estimators=750;, score=(train=0.967, test=0.902) total time=13.4min
# [CV 2/3; 17/20] START max_depth=5, max_features=None, max_samples=1.0, min_samples_leaf=2, n_estimators=750
# [CV 2/3; 16/20] END max_depth=3, max_features=None, max_samples=1.0, min_samples_leaf=8, n_estimators=750;, score=(train=0.975, test=0.754) total time=13.9min
# [CV 3/3; 17/20] START max_depth=5, max_features=None, max_samples=1.0, min_samples_leaf=2, n_estimators=750
# [CV 3/3; 16/20] END max_depth=3, max_features=None, max_samples=1.0, min_samples_leaf=8, n_estimators=750;, score=(train=0.962, test=0.954) total time=13.8min
# [CV 1/3; 18/20] START max_depth=2, max_features=sqrt, max_samples=0.5, min_samples_leaf=8, n_estimators=100
# [CV 1/3; 18/20] END max_depth=2, max_features=sqrt, max_samples=0.5, min_samples_leaf=8, n_estimators=100;, score=(train=0.988, test=0.936) total time=   5.0s
# [CV 2/3; 18/20] START max_depth=2, max_features=sqrt, max_samples=0.5, min_samples_leaf=8, n_estimators=100
# [CV 2/3; 18/20] END max_depth=2, max_features=sqrt, max_samples=0.5, min_samples_leaf=8, n_estimators=100;, score=(train=0.980, test=0.861) total time=   4.9s
# [CV 3/3; 18/20] START max_depth=2, max_features=sqrt, max_samples=0.5, min_samples_leaf=8, n_estimators=100
# [CV 3/3; 18/20] END max_depth=2, max_features=sqrt, max_samples=0.5, min_samples_leaf=8, n_estimators=100;, score=(train=0.976, test=0.955) total time=   5.6s
# [CV 1/3; 19/20] START max_depth=2, max_features=None, max_samples=0.5, min_samples_leaf=6, n_estimators=100
# [CV 1/3; 19/20] END max_depth=2, max_features=None, max_samples=0.5, min_samples_leaf=6, n_estimators=100;, score=(train=0.948, test=0.941) total time=  47.8s
# [CV 2/3; 19/20] START max_depth=2, max_features=None, max_samples=0.5, min_samples_leaf=6, n_estimators=100
# [CV 2/3; 19/20] END max_depth=2, max_features=None, max_samples=0.5, min_samples_leaf=6, n_estimators=100;, score=(train=0.959, test=0.814) total time=  48.6s
# [CV 3/3; 19/20] START max_depth=2, max_features=None, max_samples=0.5, min_samples_leaf=6, n_estimators=100
# [CV 3/3; 19/20] END max_depth=2, max_features=None, max_samples=0.5, min_samples_leaf=6, n_estimators=100;, score=(train=0.939, test=0.950) total time=  48.6s
# [CV 1/3; 20/20] START max_depth=3, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=500
# [CV 1/3; 20/20] END max_depth=3, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=500;, score=(train=0.992, test=0.932) total time=  20.0s
# [CV 2/3; 20/20] START max_depth=3, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=500
# [CV 2/3; 20/20] END max_depth=3, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=500;, score=(train=0.988, test=0.854) total time=  20.9s
# [CV 3/3; 20/20] START max_depth=3, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=500
# [CV 3/3; 20/20] END max_depth=3, max_features=log2, max_samples=1.0, min_samples_leaf=2, n_estimators=500;, score=(train=0.982, test=0.957) total time=  21.3s
# [CV 1/3; 17/20] END max_depth=5, max_features=None, max_samples=1.0, min_samples_leaf=2, n_estimators=750;, score=(train=0.987, test=0.901) total time=20.9min
# [CV 2/3; 17/20] END max_depth=5, max_features=None, max_samples=1.0, min_samples_leaf=2, n_estimators=750;, score=(train=0.986, test=0.849) total time=16.1min
# [CV 3/3; 17/20] END max_depth=5, max_features=None, max_samples=1.0, min_samples_leaf=2, n_estimators=750;, score=(train=0.982, test=0.963) total time=13.8min
# RandomizedSearchCV(cv=3, error_score='raise',
#                    estimator=RandomForestClassifier(class_weight='balanced',
#                                                     n_jobs=-1,
#                                                     random_state=42),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'max_depth': [2, 3, 5],
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'max_samples': [0.3, 0.5, 1.0],
#                                         'min_samples_leaf': [2, 6, 8],
#                                         'n_estimators': [100, 500, 750]},
#                    random_state=42, return_train_score=True, scoring='roc_auc',
#                    verbose=10)

# %%
# Getting the best model
best_model = search_obj.best_estimator_

# %%
# Showing best parameters
search_obj.best_params_
# Out:
# {'n_estimators': 750,
#  'min_samples_leaf': 8,
#  'max_samples': 0.3,
#  'max_features': 'sqrt',
#  'max_depth': 5}

# %%
# Making predictions
print('Predictions for Random Forest')
train_preds = best_model.predict_proba(X_train.values)[:,1]
valid_preds = best_model.predict_proba(X_valid.values)[:,1]
train_score = roc_auc_score(y_train,train_preds)
valid_score = roc_auc_score(y_valid,valid_preds)
print(f'Training ROC AUC: {train_score}')
print(f'Validation ROC AUC: {valid_score}')
# Out:
# Predictions for Random Forest
# Training ROC AUC: 0.9884051614184051
# Validation ROC AUC: 0.9763446142797685

# %%
# Adding the metrics
model = 'Random Forest'
performances['model'].append(model)
performances['Train ROC AUC'].append(train_score)
performances['Valid ROC AUC'].append(valid_score)

# %%
# Saving the model
with open('../../models/custom-features/noisy-grammar-errors/fine-tuned/forest-fine-noisy.pkl','wb') as file:
    pickle.dump(best_model,file)

# %% [markdown]
# ## Gradient Boosting

# %%
# Creating the balanced class sample weights
sample_weights =  X_train.shape[0] / (2.0 * np.bincount(y_train.astype(int)))

# %%
# model
catboost_clf = CatBoostClassifier(iterations=1000,loss_function='Logloss',random_seed=42,early_stopping_rounds=10,
                                  eval_metric='AUC',class_weights=sample_weights)

# Parameter grid
param_grid = {
    'learning_rate':[0.01,0.03,0.3],
    'depth':[2,3,5],
    'l2_leaf_reg':[1,3,7],
    'min_data_in_leaf':[1,5,15]
}

# %%
# Performing randomized search
search_results = catboost_clf.randomized_search(param_grid,X_train.values,y_train,cv=3,n_iter=10,refit=True,shuffle=True)
# Out:
# 0:	test: 0.9381435	best: 0.9381435 (0)	total: 185ms	remaining: 3m 4s
# 1:	test: 0.9388241	best: 0.9388241 (1)	total: 292ms	remaining: 2m 25s
# 2:	test: 0.9409334	best: 0.9409334 (2)	total: 396ms	remaining: 2m 11s
# 3:	test: 0.9417026	best: 0.9417026 (3)	total: 546ms	remaining: 2m 15s
# 4:	test: 0.9417031	best: 0.9417031 (4)	total: 739ms	remaining: 2m 27s
# 5:	test: 0.9443461	best: 0.9443461 (5)	total: 848ms	remaining: 2m 20s
# 6:	test: 0.9511140	best: 0.9511140 (6)	total: 1.04s	remaining: 2m 28s
# 7:	test: 0.9511157	best: 0.9511157 (7)	total: 1.16s	remaining: 2m 23s
# 8:	test: 0.9511914	best: 0.9511914 (8)	total: 2.15s	remaining: 3m 56s
# 9:	test: 0.9511869	best: 0.9511914 (8)	total: 2.25s	remaining: 3m 43s
# 10:	test: 0.9511890	best: 0.9511914 (8)	total: 2.41s	remaining: 3m 36s
# 11:	test: 0.9511978	best: 0.9511978 (11)	total: 2.53s	remaining: 3m 28s
# 12:	test: 0.9511886	best: 0.9511978 (11)	total: 2.63s	remaining: 3m 20s
# 13:	test: 0.9513660	best: 0.9513660 (13)	total: 2.79s	remaining: 3m 16s
# 14:	test: 0.9513924	best: 0.9513924 (14)	total: 2.91s	remaining: 3m 10s
# 15:	test: 0.9513860	best: 0.9513924 (14)	total: 3.03s	remaining: 3m 6s
# 16:	test: 0.9514598	best: 0.9514598 (16)	total: 3.15s	remaining: 3m 2s
# 17:	test: 0.9514559	best: 0.9514598 (16)	total: 3.28s	remaining: 2m 59s
# 18:	test: 0.9514559	best: 0.9514598 (16)	total: 3.38s	remaining: 2m 54s
# 19:	test: 0.9514559	best: 0.9514598 (16)	total: 3.51s	remaining: 2m 51s
# 20:	test: 0.9514559	best: 0.9514598 (16)	total: 3.65s	remaining: 2m 50s
# 21:	test: 0.9634701	best: 0.9634701 (21)	total: 3.76s	remaining: 2m 46s
# 22:	test: 0.9653011	best: 0.9653011 (22)	total: 3.89s	remaining: 2m 45s
# 23:	test: 0.9651549	best: 0.9653011 (22)	total: 4s	remaining: 2m 42s
# 24:	test: 0.9660620	best: 0.9660620 (24)	total: 4.13s	remaining: 2m 41s
# 25:	test: 0.9658314	best: 0.9660620 (24)	total: 4.24s	remaining: 2m 38s
# 26:	test: 0.9660253	best: 0.9660620 (24)	total: 4.34s	remaining: 2m 36s
# 27:	test: 0.9664427	best: 0.9664427 (27)	total: 4.49s	remaining: 2m 35s
# 28:	test: 0.9666920	best: 0.9666920 (28)	total: 4.63s	remaining: 2m 35s
# 29:	test: 0.9672358	best: 0.9672358 (29)	total: 4.73s	remaining: 2m 32s
# 30:	test: 0.9675286	best: 0.9675286 (30)	total: 4.83s	remaining: 2m 30s
# 31:	test: 0.9676978	best: 0.9676978 (31)	total: 4.95s	remaining: 2m 29s
# 32:	test: 0.9676113	best: 0.9676978 (31)	total: 5.05s	remaining: 2m 27s
# 33:	test: 0.9678562	best: 0.9678562 (33)	total: 5.14s	remaining: 2m 26s
# 34:	test: 0.9680635	best: 0.9680635 (34)	total: 5.25s	remaining: 2m 24s
# 35:	test: 0.9683372	best: 0.9683372 (35)	total: 5.34s	remaining: 2m 23s
# 36:	test: 0.9689245	best: 0.9689245 (36)	total: 5.44s	remaining: 2m 21s
# 37:	test: 0.9688778	best: 0.9689245 (36)	total: 5.54s	remaining: 2m 20s
# 38:	test: 0.9688816	best: 0.9689245 (36)	total: 5.64s	remaining: 2m 19s
# 39:	test: 0.9692121	best: 0.9692121 (39)	total: 5.74s	remaining: 2m 17s
# 40:	test: 0.9695466	best: 0.9695466 (40)	total: 5.84s	remaining: 2m 16s
# 41:	test: 0.9698532	best: 0.9698532 (41)	total: 5.96s	remaining: 2m 15s
# 42:	test: 0.9700180	best: 0.9700180 (42)	total: 6.16s	remaining: 2m 16s
# 43:	test: 0.9699245	best: 0.9700180 (42)	total: 6.25s	remaining: 2m 15s
# 44:	test: 0.9700678	best: 0.9700678 (44)	total: 6.39s	remaining: 2m 15s
# 45:	test: 0.9702145	best: 0.9702145 (45)	total: 6.85s	remaining: 2m 22s
# 46:	test: 0.9702093	best: 0.9702145 (45)	total: 6.95s	remaining: 2m 20s
# 47:	test: 0.9702710	best: 0.9702710 (47)	total: 7.08s	remaining: 2m 20s
# 48:	test: 0.9703446	best: 0.9703446 (48)	total: 7.18s	remaining: 2m 19s
# 49:	test: 0.9706087	best: 0.9706087 (49)	total: 7.27s	remaining: 2m 18s
# 50:	test: 0.9708239	best: 0.9708239 (50)	total: 7.38s	remaining: 2m 17s
# 51:	test: 0.9709390	best: 0.9709390 (51)	total: 7.48s	remaining: 2m 16s
# 52:	test: 0.9713640	best: 0.9713640 (52)	total: 7.58s	remaining: 2m 15s
# 53:	test: 0.9714739	best: 0.9714739 (53)	total: 7.69s	remaining: 2m 14s
# 54:	test: 0.9716567	best: 0.9716567 (54)	total: 7.79s	remaining: 2m 13s
# 55:	test: 0.9718107	best: 0.9718107 (55)	total: 7.89s	remaining: 2m 12s
# 56:	test: 0.9719202	best: 0.9719202 (56)	total: 8s	remaining: 2m 12s
# 57:	test: 0.9721580	best: 0.9721580 (57)	total: 8.1s	remaining: 2m 11s
# 58:	test: 0.9725320	best: 0.9725320 (58)	total: 8.2s	remaining: 2m 10s
# 59:	test: 0.9726380	best: 0.9726380 (59)	total: 8.3s	remaining: 2m 10s
# 60:	test: 0.9728839	best: 0.9728839 (60)	total: 8.42s	remaining: 2m 9s
# 61:	test: 0.9729478	best: 0.9729478 (61)	total: 8.5s	remaining: 2m 8s
# 62:	test: 0.9730338	best: 0.9730338 (62)	total: 8.59s	remaining: 2m 7s
# 63:	test: 0.9731618	best: 0.9731618 (63)	total: 8.69s	remaining: 2m 7s
# 64:	test: 0.9732348	best: 0.9732348 (64)	total: 8.78s	remaining: 2m 6s
# 65:	test: 0.9734303	best: 0.9734303 (65)	total: 8.88s	remaining: 2m 5s
# 66:	test: 0.9736871	best: 0.9736871 (66)	total: 8.98s	remaining: 2m 5s
# 67:	test: 0.9738107	best: 0.9738107 (67)	total: 9.07s	remaining: 2m 4s
# 68:	test: 0.9740126	best: 0.9740126 (68)	total: 9.17s	remaining: 2m 3s
# 69:	test: 0.9743978	best: 0.9743978 (69)	total: 9.27s	remaining: 2m 3s
# 70:	test: 0.9744926	best: 0.9744926 (70)	total: 9.37s	remaining: 2m 2s
# 71:	test: 0.9745839	best: 0.9745839 (71)	total: 9.49s	remaining: 2m 2s
# 72:	test: 0.9746424	best: 0.9746424 (72)	total: 9.58s	remaining: 2m 1s
# 73:	test: 0.9749219	best: 0.9749219 (73)	total: 9.68s	remaining: 2m 1s
# 74:	test: 0.9749615	best: 0.9749615 (74)	total: 9.79s	remaining: 2m
# 75:	test: 0.9751021	best: 0.9751021 (75)	total: 9.89s	remaining: 2m
# 76:	test: 0.9751878	best: 0.9751878 (76)	total: 9.98s	remaining: 1m 59s
# 77:	test: 0.9752164	best: 0.9752164 (77)	total: 10.1s	remaining: 1m 59s
# 78:	test: 0.9754208	best: 0.9754208 (78)	total: 10.2s	remaining: 1m 58s
# 79:	test: 0.9754376	best: 0.9754376 (79)	total: 10.3s	remaining: 1m 58s
# 80:	test: 0.9754984	best: 0.9754984 (80)	total: 10.4s	remaining: 1m 57s
# 81:	test: 0.9756917	best: 0.9756917 (81)	total: 10.5s	remaining: 1m 57s
# 82:	test: 0.9757288	best: 0.9757288 (82)	total: 10.6s	remaining: 1m 56s
# 83:	test: 0.9758377	best: 0.9758377 (83)	total: 10.7s	remaining: 1m 56s
# 84:	test: 0.9761443	best: 0.9761443 (84)	total: 10.8s	remaining: 1m 56s
# 85:	test: 0.9761068	best: 0.9761443 (84)	total: 10.9s	remaining: 1m 55s
# 86:	test: 0.9762420	best: 0.9762420 (86)	total: 11s	remaining: 1m 55s
# 87:	test: 0.9763217	best: 0.9763217 (87)	total: 11.1s	remaining: 1m 54s
# 88:	test: 0.9763931	best: 0.9763931 (88)	total: 11.2s	remaining: 1m 54s
# 89:	test: 0.9763908	best: 0.9763931 (88)	total: 11.3s	remaining: 1m 54s
# 90:	test: 0.9766010	best: 0.9766010 (90)	total: 11.4s	remaining: 1m 53s
# 91:	test: 0.9767514	best: 0.9767514 (91)	total: 11.8s	remaining: 1m 56s
# 92:	test: 0.9767861	best: 0.9767861 (92)	total: 11.9s	remaining: 1m 56s
# 93:	test: 0.9769185	best: 0.9769185 (93)	total: 12s	remaining: 1m 55s
# 94:	test: 0.9769676	best: 0.9769676 (94)	total: 12.1s	remaining: 1m 55s
# 95:	test: 0.9770001	best: 0.9770001 (95)	total: 12.2s	remaining: 1m 55s
# 96:	test: 0.9772086	best: 0.9772086 (96)	total: 12.3s	remaining: 1m 54s
# 97:	test: 0.9772306	best: 0.9772306 (97)	total: 12.4s	remaining: 1m 54s
# 98:	test: 0.9773992	best: 0.9773992 (98)	total: 12.5s	remaining: 1m 53s
# 99:	test: 0.9775087	best: 0.9775087 (99)	total: 12.6s	remaining: 1m 53s
# 100:	test: 0.9776013	best: 0.9776013 (100)	total: 12.7s	remaining: 1m 53s
# 101:	test: 0.9776336	best: 0.9776336 (101)	total: 12.8s	remaining: 1m 52s
# 102:	test: 0.9778420	best: 0.9778420 (102)	total: 12.9s	remaining: 1m 52s
# 103:	test: 0.9779349	best: 0.9779349 (103)	total: 13s	remaining: 1m 52s
# 104:	test: 0.9779983	best: 0.9779983 (104)	total: 13.1s	remaining: 1m 52s
# 105:	test: 0.9780714	best: 0.9780714 (105)	total: 13.2s	remaining: 1m 51s
# 106:	test: 0.9781767	best: 0.9781767 (106)	total: 13.3s	remaining: 1m 51s
# 107:	test: 0.9783138	best: 0.9783138 (107)	total: 13.4s	remaining: 1m 50s
# 108:	test: 0.9783316	best: 0.9783316 (108)	total: 13.5s	remaining: 1m 50s
# 109:	test: 0.9784846	best: 0.9784846 (109)	total: 13.6s	remaining: 1m 50s
# 110:	test: 0.9786373	best: 0.9786373 (110)	total: 13.7s	remaining: 1m 49s
# 111:	test: 0.9786960	best: 0.9786960 (111)	total: 13.8s	remaining: 1m 49s
# 112:	test: 0.9787919	best: 0.9787919 (112)	total: 13.9s	remaining: 1m 49s
# 113:	test: 0.9788571	best: 0.9788571 (113)	total: 14s	remaining: 1m 48s
# 114:	test: 0.9789242	best: 0.9789242 (114)	total: 14.1s	remaining: 1m 48s
# 115:	test: 0.9791382	best: 0.9791382 (115)	total: 14.2s	remaining: 1m 48s
# 116:	test: 0.9792095	best: 0.9792095 (116)	total: 14.3s	remaining: 1m 47s
# 117:	test: 0.9791847	best: 0.9792095 (116)	total: 14.4s	remaining: 1m 47s
# 118:	test: 0.9792442	best: 0.9792442 (118)	total: 14.4s	remaining: 1m 46s
# 119:	test: 0.9793299	best: 0.9793299 (119)	total: 14.5s	remaining: 1m 46s
# 120:	test: 0.9794262	best: 0.9794262 (120)	total: 14.6s	remaining: 1m 46s
# 121:	test: 0.9795163	best: 0.9795163 (121)	total: 14.9s	remaining: 1m 47s
# 122:	test: 0.9795396	best: 0.9795396 (122)	total: 15s	remaining: 1m 47s
# 123:	test: 0.9796903	best: 0.9796903 (123)	total: 15.1s	remaining: 1m 46s
# 124:	test: 0.9798100	best: 0.9798100 (124)	total: 15.2s	remaining: 1m 46s
# 125:	test: 0.9798148	best: 0.9798148 (125)	total: 15.3s	remaining: 1m 46s
# 126:	test: 0.9799523	best: 0.9799523 (126)	total: 15.4s	remaining: 1m 45s
# 127:	test: 0.9800101	best: 0.9800101 (127)	total: 15.5s	remaining: 1m 45s
# 128:	test: 0.9800337	best: 0.9800337 (128)	total: 15.6s	remaining: 1m 45s
# 129:	test: 0.9801814	best: 0.9801814 (129)	total: 15.7s	remaining: 1m 44s
# 130:	test: 0.9802607	best: 0.9802607 (130)	total: 15.8s	remaining: 1m 44s
# 131:	test: 0.9803416	best: 0.9803416 (131)	total: 15.9s	remaining: 1m 44s
# 132:	test: 0.9803649	best: 0.9803649 (132)	total: 16s	remaining: 1m 44s
# 133:	test: 0.9805089	best: 0.9805089 (133)	total: 16.1s	remaining: 1m 43s
# 134:	test: 0.9805251	best: 0.9805251 (134)	total: 16.1s	remaining: 1m 43s
# 135:	test: 0.9806231	best: 0.9806231 (135)	total: 16.2s	remaining: 1m 43s
# 136:	test: 0.9807048	best: 0.9807048 (136)	total: 16.3s	remaining: 1m 42s
# 137:	test: 0.9807974	best: 0.9807974 (137)	total: 16.4s	remaining: 1m 42s
# 138:	test: 0.9808141	best: 0.9808141 (138)	total: 16.9s	remaining: 1m 44s
# 139:	test: 0.9808634	best: 0.9808634 (139)	total: 16.9s	remaining: 1m 44s
# 140:	test: 0.9809067	best: 0.9809067 (140)	total: 17s	remaining: 1m 43s
# 141:	test: 0.9809911	best: 0.9809911 (141)	total: 17.1s	remaining: 1m 43s
# 142:	test: 0.9811271	best: 0.9811271 (142)	total: 17.2s	remaining: 1m 43s
# 143:	test: 0.9811942	best: 0.9811942 (143)	total: 17.3s	remaining: 1m 42s
# 144:	test: 0.9813025	best: 0.9813025 (144)	total: 17.4s	remaining: 1m 42s
# 145:	test: 0.9813939	best: 0.9813939 (145)	total: 17.5s	remaining: 1m 42s
# 146:	test: 0.9814061	best: 0.9814061 (146)	total: 17.6s	remaining: 1m 42s
# 147:	test: 0.9815442	best: 0.9815442 (147)	total: 17.7s	remaining: 1m 41s
# 148:	test: 0.9816034	best: 0.9816034 (148)	total: 17.8s	remaining: 1m 41s
# 149:	test: 0.9816127	best: 0.9816127 (149)	total: 17.9s	remaining: 1m 41s
# 150:	test: 0.9817127	best: 0.9817127 (150)	total: 18s	remaining: 1m 41s
# 151:	test: 0.9817819	best: 0.9817819 (151)	total: 18.1s	remaining: 1m 41s
# 152:	test: 0.9818752	best: 0.9818752 (152)	total: 18.3s	remaining: 1m 41s
# 153:	test: 0.9818910	best: 0.9818910 (153)	total: 18.4s	remaining: 1m 40s
# 154:	test: 0.9818957	best: 0.9818957 (154)	total: 18.4s	remaining: 1m 40s
# 155:	test: 0.9819665	best: 0.9819665 (155)	total: 18.5s	remaining: 1m 40s
# 156:	test: 0.9820302	best: 0.9820302 (156)	total: 18.6s	remaining: 1m 40s
# 157:	test: 0.9820948	best: 0.9820948 (157)	total: 18.7s	remaining: 1m 39s
# 158:	test: 0.9821316	best: 0.9821316 (158)	total: 18.9s	remaining: 1m 39s
# 159:	test: 0.9822086	best: 0.9822086 (159)	total: 19s	remaining: 1m 39s
# 160:	test: 0.9822661	best: 0.9822661 (160)	total: 19.1s	remaining: 1m 39s
# 161:	test: 0.9822819	best: 0.9822819 (161)	total: 19.2s	remaining: 1m 39s
# 162:	test: 0.9823232	best: 0.9823232 (162)	total: 19.3s	remaining: 1m 38s
# 163:	test: 0.9823820	best: 0.9823820 (163)	total: 19.3s	remaining: 1m 38s
# 164:	test: 0.9824259	best: 0.9824259 (164)	total: 19.4s	remaining: 1m 38s
# 165:	test: 0.9824926	best: 0.9824926 (165)	total: 19.5s	remaining: 1m 38s
# 166:	test: 0.9825385	best: 0.9825385 (166)	total: 19.6s	remaining: 1m 37s
# 167:	test: 0.9825881	best: 0.9825881 (167)	total: 19.7s	remaining: 1m 37s
# 168:	test: 0.9826001	best: 0.9826001 (168)	total: 19.8s	remaining: 1m 37s
# 169:	test: 0.9826663	best: 0.9826663 (169)	total: 19.9s	remaining: 1m 37s
# 170:	test: 0.9827313	best: 0.9827313 (170)	total: 20s	remaining: 1m 36s
# 171:	test: 0.9828165	best: 0.9828165 (171)	total: 20.1s	remaining: 1m 36s
# 172:	test: 0.9828759	best: 0.9828759 (172)	total: 20.2s	remaining: 1m 36s
# 173:	test: 0.9829712	best: 0.9829712 (173)	total: 20.3s	remaining: 1m 36s
# 174:	test: 0.9829865	best: 0.9829865 (174)	total: 20.3s	remaining: 1m 35s
# 175:	test: 0.9829942	best: 0.9829942 (175)	total: 20.4s	remaining: 1m 35s
# 176:	test: 0.9830413	best: 0.9830413 (176)	total: 20.5s	remaining: 1m 35s
# 177:	test: 0.9830848	best: 0.9830848 (177)	total: 20.6s	remaining: 1m 35s
# 178:	test: 0.9831289	best: 0.9831289 (178)	total: 20.7s	remaining: 1m 35s
# 179:	test: 0.9831280	best: 0.9831289 (178)	total: 20.8s	remaining: 1m 34s
# 180:	test: 0.9831735	best: 0.9831735 (180)	total: 20.9s	remaining: 1m 34s
# 181:	test: 0.9832396	best: 0.9832396 (181)	total: 21s	remaining: 1m 34s
# 182:	test: 0.9832860	best: 0.9832860 (182)	total: 21.1s	remaining: 1m 34s
# 183:	test: 0.9833284	best: 0.9833284 (183)	total: 21.2s	remaining: 1m 33s
# 184:	test: 0.9833753	best: 0.9833753 (184)	total: 21.3s	remaining: 1m 33s
# 185:	test: 0.9834262	best: 0.9834262 (185)	total: 21.4s	remaining: 1m 33s
# 186:	test: 0.9834638	best: 0.9834638 (186)	total: 21.8s	remaining: 1m 34s
# 187:	test: 0.9835008	best: 0.9835008 (187)	total: 21.9s	remaining: 1m 34s
# 188:	test: 0.9835360	best: 0.9835360 (188)	total: 22s	remaining: 1m 34s
# 189:	test: 0.9835883	best: 0.9835883 (189)	total: 22.1s	remaining: 1m 34s
# 190:	test: 0.9836415	best: 0.9836415 (190)	total: 22.2s	remaining: 1m 33s
# 191:	test: 0.9836874	best: 0.9836874 (191)	total: 22.3s	remaining: 1m 33s
# 192:	test: 0.9837131	best: 0.9837131 (192)	total: 22.4s	remaining: 1m 33s
# 193:	test: 0.9837514	best: 0.9837514 (193)	total: 22.5s	remaining: 1m 33s
# 194:	test: 0.9837998	best: 0.9837998 (194)	total: 22.6s	remaining: 1m 33s
# 195:	test: 0.9838909	best: 0.9838909 (195)	total: 22.7s	remaining: 1m 33s
# 196:	test: 0.9838939	best: 0.9838939 (196)	total: 22.8s	remaining: 1m 32s
# 197:	test: 0.9839396	best: 0.9839396 (197)	total: 22.9s	remaining: 1m 32s
# 198:	test: 0.9840203	best: 0.9840203 (198)	total: 23s	remaining: 1m 32s
# 199:	test: 0.9840652	best: 0.9840652 (199)	total: 23.1s	remaining: 1m 32s
# 200:	test: 0.9840748	best: 0.9840748 (200)	total: 23.1s	remaining: 1m 31s
# 201:	test: 0.9841467	best: 0.9841467 (201)	total: 23.3s	remaining: 1m 31s
# 202:	test: 0.9841899	best: 0.9841899 (202)	total: 23.3s	remaining: 1m 31s
# 203:	test: 0.9841757	best: 0.9841899 (202)	total: 23.4s	remaining: 1m 31s
# 204:	test: 0.9842201	best: 0.9842201 (204)	total: 23.5s	remaining: 1m 31s
# 205:	test: 0.9842731	best: 0.9842731 (205)	total: 23.6s	remaining: 1m 31s
# 206:	test: 0.9843707	best: 0.9843707 (206)	total: 23.7s	remaining: 1m 30s
# 207:	test: 0.9844228	best: 0.9844228 (207)	total: 23.8s	remaining: 1m 30s
# 208:	test: 0.9844485	best: 0.9844485 (208)	total: 23.9s	remaining: 1m 30s
# 209:	test: 0.9844756	best: 0.9844756 (209)	total: 24s	remaining: 1m 30s
# 210:	test: 0.9845384	best: 0.9845384 (210)	total: 24.1s	remaining: 1m 30s
# 211:	test: 0.9845973	best: 0.9845973 (211)	total: 24.2s	remaining: 1m 29s
# 212:	test: 0.9846184	best: 0.9846184 (212)	total: 24.3s	remaining: 1m 29s
# 213:	test: 0.9846610	best: 0.9846610 (213)	total: 24.4s	remaining: 1m 29s
# 214:	test: 0.9846661	best: 0.9846661 (214)	total: 24.5s	remaining: 1m 29s
# 215:	test: 0.9846745	best: 0.9846745 (215)	total: 24.6s	remaining: 1m 29s
# 216:	test: 0.9847172	best: 0.9847172 (216)	total: 24.7s	remaining: 1m 29s
# 217:	test: 0.9847480	best: 0.9847480 (217)	total: 24.8s	remaining: 1m 28s
# 218:	test: 0.9847799	best: 0.9847799 (218)	total: 24.9s	remaining: 1m 28s
# 219:	test: 0.9848161	best: 0.9848161 (219)	total: 25s	remaining: 1m 28s
# 220:	test: 0.9848552	best: 0.9848552 (220)	total: 25.1s	remaining: 1m 28s
# 221:	test: 0.9849024	best: 0.9849024 (221)	total: 25.2s	remaining: 1m 28s
# 222:	test: 0.9849339	best: 0.9849339 (222)	total: 25.3s	remaining: 1m 28s
# 223:	test: 0.9849613	best: 0.9849613 (223)	total: 25.4s	remaining: 1m 27s
# 224:	test: 0.9850125	best: 0.9850125 (224)	total: 25.5s	remaining: 1m 27s
# 225:	test: 0.9850176	best: 0.9850176 (225)	total: 25.6s	remaining: 1m 27s
# 226:	test: 0.9850532	best: 0.9850532 (226)	total: 25.7s	remaining: 1m 27s
# 227:	test: 0.9850930	best: 0.9850930 (227)	total: 25.7s	remaining: 1m 27s
# 228:	test: 0.9851331	best: 0.9851331 (228)	total: 25.9s	remaining: 1m 27s
# 229:	test: 0.9851700	best: 0.9851700 (229)	total: 25.9s	remaining: 1m 26s
# 230:	test: 0.9851946	best: 0.9851946 (230)	total: 26s	remaining: 1m 26s
# 231:	test: 0.9852357	best: 0.9852357 (231)	total: 26.1s	remaining: 1m 26s
# 232:	test: 0.9852730	best: 0.9852730 (232)	total: 26.2s	remaining: 1m 26s
# 233:	test: 0.9853150	best: 0.9853150 (233)	total: 26.3s	remaining: 1m 26s
# 234:	test: 0.9853121	best: 0.9853150 (233)	total: 26.4s	remaining: 1m 25s
# 235:	test: 0.9853517	best: 0.9853517 (235)	total: 26.9s	remaining: 1m 26s
# 236:	test: 0.9854218	best: 0.9854218 (236)	total: 27s	remaining: 1m 26s
# 237:	test: 0.9854678	best: 0.9854678 (237)	total: 27.1s	remaining: 1m 26s
# 238:	test: 0.9855018	best: 0.9855018 (238)	total: 27.2s	remaining: 1m 26s
# 239:	test: 0.9855354	best: 0.9855354 (239)	total: 27.3s	remaining: 1m 26s
# 240:	test: 0.9855626	best: 0.9855626 (240)	total: 27.3s	remaining: 1m 26s
# 241:	test: 0.9855748	best: 0.9855748 (241)	total: 27.4s	remaining: 1m 25s
# 242:	test: 0.9856131	best: 0.9856131 (242)	total: 27.5s	remaining: 1m 25s
# 243:	test: 0.9856447	best: 0.9856447 (243)	total: 27.6s	remaining: 1m 25s
# 244:	test: 0.9856936	best: 0.9856936 (244)	total: 27.7s	remaining: 1m 25s
# 245:	test: 0.9857197	best: 0.9857197 (245)	total: 27.8s	remaining: 1m 25s
# 246:	test: 0.9857578	best: 0.9857578 (246)	total: 27.9s	remaining: 1m 25s
# 247:	test: 0.9857734	best: 0.9857734 (247)	total: 28s	remaining: 1m 24s
# 248:	test: 0.9857972	best: 0.9857972 (248)	total: 28.1s	remaining: 1m 24s
# 249:	test: 0.9858146	best: 0.9858146 (249)	total: 28.2s	remaining: 1m 24s
# 250:	test: 0.9858423	best: 0.9858423 (250)	total: 28.3s	remaining: 1m 24s
# 251:	test: 0.9858819	best: 0.9858819 (251)	total: 28.4s	remaining: 1m 24s
# 252:	test: 0.9859248	best: 0.9859248 (252)	total: 28.5s	remaining: 1m 24s
# 253:	test: 0.9859616	best: 0.9859616 (253)	total: 28.6s	remaining: 1m 24s
# 254:	test: 0.9859803	best: 0.9859803 (254)	total: 28.7s	remaining: 1m 23s
# 255:	test: 0.9860173	best: 0.9860173 (255)	total: 28.8s	remaining: 1m 23s
# 256:	test: 0.9860738	best: 0.9860738 (256)	total: 28.9s	remaining: 1m 23s
# 257:	test: 0.9861068	best: 0.9861068 (257)	total: 29s	remaining: 1m 23s
# 258:	test: 0.9861354	best: 0.9861354 (258)	total: 29.1s	remaining: 1m 23s
# 259:	test: 0.9861606	best: 0.9861606 (259)	total: 29.2s	remaining: 1m 22s
# 260:	test: 0.9861660	best: 0.9861660 (260)	total: 29.2s	remaining: 1m 22s
# 261:	test: 0.9861977	best: 0.9861977 (261)	total: 29.3s	remaining: 1m 22s
# 262:	test: 0.9862245	best: 0.9862245 (262)	total: 29.4s	remaining: 1m 22s
# 263:	test: 0.9862516	best: 0.9862516 (263)	total: 29.5s	remaining: 1m 22s
# 264:	test: 0.9862830	best: 0.9862830 (264)	total: 29.6s	remaining: 1m 22s
# 265:	test: 0.9863095	best: 0.9863095 (265)	total: 29.7s	remaining: 1m 21s
# 266:	test: 0.9863423	best: 0.9863423 (266)	total: 29.8s	remaining: 1m 21s
# 267:	test: 0.9863691	best: 0.9863691 (267)	total: 29.9s	remaining: 1m 21s
# 268:	test: 0.9863977	best: 0.9863977 (268)	total: 30.3s	remaining: 1m 22s
# 269:	test: 0.9864270	best: 0.9864270 (269)	total: 30.4s	remaining: 1m 22s
# 270:	test: 0.9864584	best: 0.9864584 (270)	total: 30.5s	remaining: 1m 21s
# 271:	test: 0.9864736	best: 0.9864736 (271)	total: 30.6s	remaining: 1m 21s
# 272:	test: 0.9864930	best: 0.9864930 (272)	total: 30.7s	remaining: 1m 21s
# 273:	test: 0.9865154	best: 0.9865154 (273)	total: 30.7s	remaining: 1m 21s
# 274:	test: 0.9865325	best: 0.9865325 (274)	total: 30.8s	remaining: 1m 21s
# 275:	test: 0.9865882	best: 0.9865882 (275)	total: 30.9s	remaining: 1m 21s
# 276:	test: 0.9866125	best: 0.9866125 (276)	total: 31s	remaining: 1m 21s
# 277:	test: 0.9866331	best: 0.9866331 (277)	total: 31.1s	remaining: 1m 20s
# 278:	test: 0.9866350	best: 0.9866350 (278)	total: 31.2s	remaining: 1m 20s
# 279:	test: 0.9866373	best: 0.9866373 (279)	total: 31.3s	remaining: 1m 20s
# 280:	test: 0.9866417	best: 0.9866417 (280)	total: 31.4s	remaining: 1m 20s
# 281:	test: 0.9866786	best: 0.9866786 (281)	total: 31.8s	remaining: 1m 21s
# 282:	test: 0.9867050	best: 0.9867050 (282)	total: 31.9s	remaining: 1m 20s
# 283:	test: 0.9867182	best: 0.9867182 (283)	total: 32s	remaining: 1m 20s
# 284:	test: 0.9867473	best: 0.9867473 (284)	total: 32.1s	remaining: 1m 20s
# 285:	test: 0.9867645	best: 0.9867645 (285)	total: 32.2s	remaining: 1m 20s
# 286:	test: 0.9867852	best: 0.9867852 (286)	total: 32.3s	remaining: 1m 20s
# 287:	test: 0.9868075	best: 0.9868075 (287)	total: 32.4s	remaining: 1m 20s
# 288:	test: 0.9868309	best: 0.9868309 (288)	total: 32.5s	remaining: 1m 19s
# 289:	test: 0.9868563	best: 0.9868563 (289)	total: 32.6s	remaining: 1m 19s
# 290:	test: 0.9868794	best: 0.9868794 (290)	total: 32.7s	remaining: 1m 19s
# 291:	test: 0.9868858	best: 0.9868858 (291)	total: 32.8s	remaining: 1m 19s
# 292:	test: 0.9869124	best: 0.9869124 (292)	total: 33s	remaining: 1m 19s
# 293:	test: 0.9869363	best: 0.9869363 (293)	total: 33.1s	remaining: 1m 19s
# 294:	test: 0.9869676	best: 0.9869676 (294)	total: 33.1s	remaining: 1m 19s
# 295:	test: 0.9869703	best: 0.9869703 (295)	total: 33.2s	remaining: 1m 19s
# 296:	test: 0.9870054	best: 0.9870054 (296)	total: 33.3s	remaining: 1m 18s
# 297:	test: 0.9870313	best: 0.9870313 (297)	total: 33.4s	remaining: 1m 18s
# 298:	test: 0.9870523	best: 0.9870523 (298)	total: 33.5s	remaining: 1m 18s
# 299:	test: 0.9870644	best: 0.9870644 (299)	total: 33.6s	remaining: 1m 18s
# 300:	test: 0.9870862	best: 0.9870862 (300)	total: 33.7s	remaining: 1m 18s
# 301:	test: 0.9871041	best: 0.9871041 (301)	total: 33.8s	remaining: 1m 18s
# 302:	test: 0.9871226	best: 0.9871226 (302)	total: 33.9s	remaining: 1m 17s
# 303:	test: 0.9871418	best: 0.9871418 (303)	total: 34s	remaining: 1m 17s
# 304:	test: 0.9871589	best: 0.9871589 (304)	total: 34.1s	remaining: 1m 17s
# 305:	test: 0.9871749	best: 0.9871749 (305)	total: 34.2s	remaining: 1m 17s
# 306:	test: 0.9872014	best: 0.9872014 (306)	total: 34.2s	remaining: 1m 17s
# 307:	test: 0.9872369	best: 0.9872369 (307)	total: 34.4s	remaining: 1m 17s
# 308:	test: 0.9872641	best: 0.9872641 (308)	total: 34.4s	remaining: 1m 17s
# 309:	test: 0.9872953	best: 0.9872953 (309)	total: 34.5s	remaining: 1m 16s
# 310:	test: 0.9873141	best: 0.9873141 (310)	total: 34.6s	remaining: 1m 16s
# 311:	test: 0.9873213	best: 0.9873213 (311)	total: 34.7s	remaining: 1m 16s
# 312:	test: 0.9873252	best: 0.9873252 (312)	total: 34.8s	remaining: 1m 16s
# 313:	test: 0.9873429	best: 0.9873429 (313)	total: 34.9s	remaining: 1m 16s
# 314:	test: 0.9873734	best: 0.9873734 (314)	total: 35s	remaining: 1m 16s
# 315:	test: 0.9873964	best: 0.9873964 (315)	total: 35.1s	remaining: 1m 16s
# 316:	test: 0.9874247	best: 0.9874247 (316)	total: 35.2s	remaining: 1m 15s
# 317:	test: 0.9874480	best: 0.9874480 (317)	total: 35.3s	remaining: 1m 15s
# 318:	test: 0.9874717	best: 0.9874717 (318)	total: 35.4s	remaining: 1m 15s
# 319:	test: 0.9874836	best: 0.9874836 (319)	total: 35.5s	remaining: 1m 15s
# 320:	test: 0.9875174	best: 0.9875174 (320)	total: 35.6s	remaining: 1m 15s
# 321:	test: 0.9875349	best: 0.9875349 (321)	total: 35.7s	remaining: 1m 15s
# 322:	test: 0.9875507	best: 0.9875507 (322)	total: 35.8s	remaining: 1m 15s
# 323:	test: 0.9875653	best: 0.9875653 (323)	total: 35.9s	remaining: 1m 14s
# 324:	test: 0.9875927	best: 0.9875927 (324)	total: 36s	remaining: 1m 14s
# 325:	test: 0.9876240	best: 0.9876240 (325)	total: 36.1s	remaining: 1m 14s
# 326:	test: 0.9876525	best: 0.9876525 (326)	total: 36.2s	remaining: 1m 14s
# 327:	test: 0.9876727	best: 0.9876727 (327)	total: 36.3s	remaining: 1m 14s
# 328:	test: 0.9877066	best: 0.9877066 (328)	total: 36.3s	remaining: 1m 14s
# 329:	test: 0.9877308	best: 0.9877308 (329)	total: 36.4s	remaining: 1m 14s
# 330:	test: 0.9877588	best: 0.9877588 (330)	total: 36.9s	remaining: 1m 14s
# 331:	test: 0.9877823	best: 0.9877823 (331)	total: 37s	remaining: 1m 14s
# 332:	test: 0.9878061	best: 0.9878061 (332)	total: 37.1s	remaining: 1m 14s
# 333:	test: 0.9878121	best: 0.9878121 (333)	total: 37.2s	remaining: 1m 14s
# 334:	test: 0.9878177	best: 0.9878177 (334)	total: 37.2s	remaining: 1m 13s
# 335:	test: 0.9878573	best: 0.9878573 (335)	total: 37.3s	remaining: 1m 13s
# 336:	test: 0.9878847	best: 0.9878847 (336)	total: 37.4s	remaining: 1m 13s
# 337:	test: 0.9878980	best: 0.9878980 (337)	total: 37.5s	remaining: 1m 13s
# 338:	test: 0.9879170	best: 0.9879170 (338)	total: 37.6s	remaining: 1m 13s
# 339:	test: 0.9879424	best: 0.9879424 (339)	total: 37.7s	remaining: 1m 13s
# 340:	test: 0.9879803	best: 0.9879803 (340)	total: 37.8s	remaining: 1m 12s
# 341:	test: 0.9880033	best: 0.9880033 (341)	total: 37.9s	remaining: 1m 12s
# 342:	test: 0.9880139	best: 0.9880139 (342)	total: 38s	remaining: 1m 12s
# 343:	test: 0.9880329	best: 0.9880329 (343)	total: 38.1s	remaining: 1m 12s
# 344:	test: 0.9880743	best: 0.9880743 (344)	total: 38.1s	remaining: 1m 12s
# 345:	test: 0.9880880	best: 0.9880880 (345)	total: 38.2s	remaining: 1m 12s
# 346:	test: 0.9881050	best: 0.9881050 (346)	total: 38.3s	remaining: 1m 12s
# 347:	test: 0.9881258	best: 0.9881258 (347)	total: 38.4s	remaining: 1m 11s
# 348:	test: 0.9881393	best: 0.9881393 (348)	total: 38.5s	remaining: 1m 11s
# 349:	test: 0.9881415	best: 0.9881415 (349)	total: 38.6s	remaining: 1m 11s
# 350:	test: 0.9881469	best: 0.9881469 (350)	total: 38.7s	remaining: 1m 11s
# 351:	test: 0.9881588	best: 0.9881588 (351)	total: 38.8s	remaining: 1m 11s
# 352:	test: 0.9881806	best: 0.9881806 (352)	total: 38.9s	remaining: 1m 11s
# 353:	test: 0.9882068	best: 0.9882068 (353)	total: 38.9s	remaining: 1m 11s
# 354:	test: 0.9882323	best: 0.9882323 (354)	total: 39s	remaining: 1m 10s
# 355:	test: 0.9882510	best: 0.9882510 (355)	total: 39.1s	remaining: 1m 10s
# 356:	test: 0.9882791	best: 0.9882791 (356)	total: 39.2s	remaining: 1m 10s
# 357:	test: 0.9882966	best: 0.9882966 (357)	total: 39.3s	remaining: 1m 10s
# 358:	test: 0.9883210	best: 0.9883210 (358)	total: 39.4s	remaining: 1m 10s
# 359:	test: 0.9883300	best: 0.9883300 (359)	total: 39.5s	remaining: 1m 10s
# 360:	test: 0.9883522	best: 0.9883522 (360)	total: 39.6s	remaining: 1m 10s
# 361:	test: 0.9883539	best: 0.9883539 (361)	total: 39.7s	remaining: 1m 9s
# 362:	test: 0.9883752	best: 0.9883752 (362)	total: 39.8s	remaining: 1m 9s
# 363:	test: 0.9883868	best: 0.9883868 (363)	total: 39.9s	remaining: 1m 9s
# 364:	test: 0.9883885	best: 0.9883885 (364)	total: 40s	remaining: 1m 9s
# 365:	test: 0.9883959	best: 0.9883959 (365)	total: 40.1s	remaining: 1m 9s
# 366:	test: 0.9884053	best: 0.9884053 (366)	total: 40.2s	remaining: 1m 9s
# 367:	test: 0.9884232	best: 0.9884232 (367)	total: 40.2s	remaining: 1m 9s
# 368:	test: 0.9884296	best: 0.9884296 (368)	total: 40.3s	remaining: 1m 8s
# 369:	test: 0.9884496	best: 0.9884496 (369)	total: 40.4s	remaining: 1m 8s
# 370:	test: 0.9884461	best: 0.9884496 (369)	total: 40.5s	remaining: 1m 8s
# 371:	test: 0.9884565	best: 0.9884565 (371)	total: 40.6s	remaining: 1m 8s
# 372:	test: 0.9884782	best: 0.9884782 (372)	total: 40.7s	remaining: 1m 8s
# 373:	test: 0.9884844	best: 0.9884844 (373)	total: 40.8s	remaining: 1m 8s
# 374:	test: 0.9884864	best: 0.9884864 (374)	total: 40.9s	remaining: 1m 8s
# 375:	test: 0.9885066	best: 0.9885066 (375)	total: 41s	remaining: 1m 8s
# 376:	test: 0.9885136	best: 0.9885136 (376)	total: 41.1s	remaining: 1m 7s
# 377:	test: 0.9885342	best: 0.9885342 (377)	total: 41.2s	remaining: 1m 7s
# 378:	test: 0.9885456	best: 0.9885456 (378)	total: 41.3s	remaining: 1m 7s
# 379:	test: 0.9885516	best: 0.9885516 (379)	total: 41.4s	remaining: 1m 7s
# 380:	test: 0.9885759	best: 0.9885759 (380)	total: 41.9s	remaining: 1m 7s
# 381:	test: 0.9885872	best: 0.9885872 (381)	total: 41.9s	remaining: 1m 7s
# 382:	test: 0.9885933	best: 0.9885933 (382)	total: 42s	remaining: 1m 7s
# 383:	test: 0.9886158	best: 0.9886158 (383)	total: 42.1s	remaining: 1m 7s
# 384:	test: 0.9886391	best: 0.9886391 (384)	total: 42.2s	remaining: 1m 7s
# 385:	test: 0.9886597	best: 0.9886597 (385)	total: 42.3s	remaining: 1m 7s
# 386:	test: 0.9886676	best: 0.9886676 (386)	total: 42.4s	remaining: 1m 7s
# 387:	test: 0.9886904	best: 0.9886904 (387)	total: 42.5s	remaining: 1m 7s
# 388:	test: 0.9887140	best: 0.9887140 (388)	total: 42.6s	remaining: 1m 6s
# 389:	test: 0.9887242	best: 0.9887242 (389)	total: 42.7s	remaining: 1m 6s
# 390:	test: 0.9887426	best: 0.9887426 (390)	total: 42.8s	remaining: 1m 6s
# 391:	test: 0.9887467	best: 0.9887467 (391)	total: 42.9s	remaining: 1m 6s
# 392:	test: 0.9887591	best: 0.9887591 (392)	total: 43s	remaining: 1m 6s
# 393:	test: 0.9887683	best: 0.9887683 (393)	total: 43.1s	remaining: 1m 6s
# 394:	test: 0.9887797	best: 0.9887797 (394)	total: 43.2s	remaining: 1m 6s
# 395:	test: 0.9887922	best: 0.9887922 (395)	total: 43.3s	remaining: 1m 6s
# 396:	test: 0.9888064	best: 0.9888064 (396)	total: 43.4s	remaining: 1m 5s
# 397:	test: 0.9888198	best: 0.9888198 (397)	total: 43.5s	remaining: 1m 5s
# 398:	test: 0.9888199	best: 0.9888199 (398)	total: 43.6s	remaining: 1m 5s
# 399:	test: 0.9888314	best: 0.9888314 (399)	total: 43.6s	remaining: 1m 5s
# 400:	test: 0.9888405	best: 0.9888405 (400)	total: 43.7s	remaining: 1m 5s
# 401:	test: 0.9888601	best: 0.9888601 (401)	total: 43.8s	remaining: 1m 5s
# 402:	test: 0.9888656	best: 0.9888656 (402)	total: 43.9s	remaining: 1m 5s
# 403:	test: 0.9888770	best: 0.9888770 (403)	total: 44s	remaining: 1m 4s
# 404:	test: 0.9888865	best: 0.9888865 (404)	total: 44.1s	remaining: 1m 4s
# 405:	test: 0.9888932	best: 0.9888932 (405)	total: 44.2s	remaining: 1m 4s
# 406:	test: 0.9889152	best: 0.9889152 (406)	total: 44.3s	remaining: 1m 4s
# 407:	test: 0.9889302	best: 0.9889302 (407)	total: 44.4s	remaining: 1m 4s
# 408:	test: 0.9889475	best: 0.9889475 (408)	total: 44.5s	remaining: 1m 4s
# 409:	test: 0.9889709	best: 0.9889709 (409)	total: 44.5s	remaining: 1m 4s
# 410:	test: 0.9889766	best: 0.9889766 (410)	total: 44.6s	remaining: 1m 3s
# 411:	test: 0.9890123	best: 0.9890123 (411)	total: 44.8s	remaining: 1m 3s
# 412:	test: 0.9890176	best: 0.9890176 (412)	total: 44.9s	remaining: 1m 3s
# 413:	test: 0.9890364	best: 0.9890364 (413)	total: 44.9s	remaining: 1m 3s
# 414:	test: 0.9890501	best: 0.9890501 (414)	total: 45s	remaining: 1m 3s
# 415:	test: 0.9890525	best: 0.9890525 (415)	total: 45.3s	remaining: 1m 3s
# 416:	test: 0.9890703	best: 0.9890703 (416)	total: 45.4s	remaining: 1m 3s
# 417:	test: 0.9890806	best: 0.9890806 (417)	total: 45.5s	remaining: 1m 3s
# 418:	test: 0.9890888	best: 0.9890888 (418)	total: 45.6s	remaining: 1m 3s
# 419:	test: 0.9890966	best: 0.9890966 (419)	total: 45.7s	remaining: 1m 3s
# 420:	test: 0.9891150	best: 0.9891150 (420)	total: 45.8s	remaining: 1m 3s
# 421:	test: 0.9891276	best: 0.9891276 (421)	total: 45.9s	remaining: 1m 2s
# 422:	test: 0.9891441	best: 0.9891441 (422)	total: 46s	remaining: 1m 2s
# 423:	test: 0.9891577	best: 0.9891577 (423)	total: 46.1s	remaining: 1m 2s
# 424:	test: 0.9891727	best: 0.9891727 (424)	total: 46.2s	remaining: 1m 2s
# 425:	test: 0.9891800	best: 0.9891800 (425)	total: 46.3s	remaining: 1m 2s
# 426:	test: 0.9891889	best: 0.9891889 (426)	total: 46.4s	remaining: 1m 2s
# 427:	test: 0.9891890	best: 0.9891890 (427)	total: 46.8s	remaining: 1m 2s
# 428:	test: 0.9892022	best: 0.9892022 (428)	total: 46.9s	remaining: 1m 2s
# 429:	test: 0.9892183	best: 0.9892183 (429)	total: 47s	remaining: 1m 2s
# 430:	test: 0.9892377	best: 0.9892377 (430)	total: 47.1s	remaining: 1m 2s
# 431:	test: 0.9892557	best: 0.9892557 (431)	total: 47.2s	remaining: 1m 2s
# 432:	test: 0.9892724	best: 0.9892724 (432)	total: 47.3s	remaining: 1m 1s
# 433:	test: 0.9892879	best: 0.9892879 (433)	total: 47.4s	remaining: 1m 1s
# 434:	test: 0.9892975	best: 0.9892975 (434)	total: 47.5s	remaining: 1m 1s
# 435:	test: 0.9893224	best: 0.9893224 (435)	total: 47.5s	remaining: 1m 1s
# 436:	test: 0.9893257	best: 0.9893257 (436)	total: 47.6s	remaining: 1m 1s
# 437:	test: 0.9893402	best: 0.9893402 (437)	total: 47.7s	remaining: 1m 1s
# 438:	test: 0.9893542	best: 0.9893542 (438)	total: 47.8s	remaining: 1m 1s
# 439:	test: 0.9893697	best: 0.9893697 (439)	total: 47.9s	remaining: 1m
# 440:	test: 0.9893840	best: 0.9893840 (440)	total: 48s	remaining: 1m
# 441:	test: 0.9893890	best: 0.9893890 (441)	total: 48.1s	remaining: 1m
# 442:	test: 0.9894055	best: 0.9894055 (442)	total: 48.2s	remaining: 1m
# 443:	test: 0.9894110	best: 0.9894110 (443)	total: 48.3s	remaining: 1m
# 444:	test: 0.9894300	best: 0.9894300 (444)	total: 48.4s	remaining: 1m
# 445:	test: 0.9894403	best: 0.9894403 (445)	total: 48.5s	remaining: 1m
# 446:	test: 0.9894480	best: 0.9894480 (446)	total: 48.6s	remaining: 1m
# 447:	test: 0.9894545	best: 0.9894545 (447)	total: 48.7s	remaining: 59.9s
# 448:	test: 0.9894615	best: 0.9894615 (448)	total: 48.7s	remaining: 59.8s
# 449:	test: 0.9894739	best: 0.9894739 (449)	total: 48.8s	remaining: 59.7s
# 450:	test: 0.9894846	best: 0.9894846 (450)	total: 49s	remaining: 59.6s
# 451:	test: 0.9894956	best: 0.9894956 (451)	total: 49s	remaining: 59.5s
# 452:	test: 0.9895030	best: 0.9895030 (452)	total: 49.1s	remaining: 59.3s
# 453:	test: 0.9895102	best: 0.9895102 (453)	total: 49.2s	remaining: 59.2s
# 454:	test: 0.9895346	best: 0.9895346 (454)	total: 49.3s	remaining: 59.1s
# 455:	test: 0.9895447	best: 0.9895447 (455)	total: 49.4s	remaining: 58.9s
# 456:	test: 0.9895471	best: 0.9895471 (456)	total: 49.5s	remaining: 58.8s
# 457:	test: 0.9895584	best: 0.9895584 (457)	total: 49.6s	remaining: 58.7s
# 458:	test: 0.9895769	best: 0.9895769 (458)	total: 49.7s	remaining: 58.6s
# 459:	test: 0.9895800	best: 0.9895800 (459)	total: 49.8s	remaining: 58.4s
# 460:	test: 0.9895807	best: 0.9895807 (460)	total: 49.9s	remaining: 58.3s
# 461:	test: 0.9895902	best: 0.9895902 (461)	total: 49.9s	remaining: 58.2s
# 462:	test: 0.9895928	best: 0.9895928 (462)	total: 50.1s	remaining: 58.1s
# 463:	test: 0.9896003	best: 0.9896003 (463)	total: 50.1s	remaining: 57.9s
# 464:	test: 0.9896046	best: 0.9896046 (464)	total: 50.2s	remaining: 57.8s
# 465:	test: 0.9896401	best: 0.9896401 (465)	total: 50.3s	remaining: 57.6s
# 466:	test: 0.9896456	best: 0.9896456 (466)	total: 50.4s	remaining: 57.5s
# 467:	test: 0.9896515	best: 0.9896515 (467)	total: 50.5s	remaining: 57.4s
# 468:	test: 0.9896676	best: 0.9896676 (468)	total: 50.6s	remaining: 57.2s
# 469:	test: 0.9896837	best: 0.9896837 (469)	total: 50.6s	remaining: 57.1s
# 470:	test: 0.9896961	best: 0.9896961 (470)	total: 50.7s	remaining: 56.9s
# 471:	test: 0.9897021	best: 0.9897021 (471)	total: 50.7s	remaining: 56.8s
# 472:	test: 0.9897220	best: 0.9897220 (472)	total: 50.8s	remaining: 56.6s
# 473:	test: 0.9897226	best: 0.9897226 (473)	total: 50.9s	remaining: 56.5s
# 474:	test: 0.9897399	best: 0.9897399 (474)	total: 51s	remaining: 56.4s
# 475:	test: 0.9897505	best: 0.9897505 (475)	total: 51.1s	remaining: 56.2s
# 476:	test: 0.9897755	best: 0.9897755 (476)	total: 51.2s	remaining: 56.1s
# 477:	test: 0.9897826	best: 0.9897826 (477)	total: 51.3s	remaining: 56s
# 478:	test: 0.9898112	best: 0.9898112 (478)	total: 51.4s	remaining: 55.9s
# 479:	test: 0.9898140	best: 0.9898140 (479)	total: 51.8s	remaining: 56.2s
# 480:	test: 0.9898299	best: 0.9898299 (480)	total: 51.9s	remaining: 56s
# 481:	test: 0.9898311	best: 0.9898311 (481)	total: 52s	remaining: 55.9s
# 482:	test: 0.9898403	best: 0.9898403 (482)	total: 52.1s	remaining: 55.8s
# 483:	test: 0.9898436	best: 0.9898436 (483)	total: 52.2s	remaining: 55.7s
# 484:	test: 0.9898507	best: 0.9898507 (484)	total: 52.3s	remaining: 55.6s
# 485:	test: 0.9898582	best: 0.9898582 (485)	total: 52.4s	remaining: 55.5s
# 486:	test: 0.9898729	best: 0.9898729 (486)	total: 52.5s	remaining: 55.3s
# 487:	test: 0.9898836	best: 0.9898836 (487)	total: 52.6s	remaining: 55.2s
# 488:	test: 0.9898892	best: 0.9898892 (488)	total: 52.7s	remaining: 55.1s
# 489:	test: 0.9899049	best: 0.9899049 (489)	total: 52.8s	remaining: 55s
# 490:	test: 0.9899131	best: 0.9899131 (490)	total: 52.9s	remaining: 54.8s
# 491:	test: 0.9899411	best: 0.9899411 (491)	total: 53s	remaining: 54.8s
# 492:	test: 0.9899471	best: 0.9899471 (492)	total: 53.1s	remaining: 54.6s
# 493:	test: 0.9899540	best: 0.9899540 (493)	total: 53.2s	remaining: 54.4s
# 494:	test: 0.9899585	best: 0.9899585 (494)	total: 53.2s	remaining: 54.3s
# 495:	test: 0.9899755	best: 0.9899755 (495)	total: 53.3s	remaining: 54.2s
# 496:	test: 0.9899841	best: 0.9899841 (496)	total: 53.4s	remaining: 54s
# 497:	test: 0.9899986	best: 0.9899986 (497)	total: 53.5s	remaining: 53.9s
# 498:	test: 0.9899991	best: 0.9899991 (498)	total: 53.6s	remaining: 53.8s
# 499:	test: 0.9900142	best: 0.9900142 (499)	total: 53.7s	remaining: 53.7s
# 500:	test: 0.9900238	best: 0.9900238 (500)	total: 53.8s	remaining: 53.6s
# 501:	test: 0.9900329	best: 0.9900329 (501)	total: 53.9s	remaining: 53.4s
# 502:	test: 0.9900386	best: 0.9900386 (502)	total: 54s	remaining: 53.3s
# 503:	test: 0.9900480	best: 0.9900480 (503)	total: 54s	remaining: 53.2s
# 504:	test: 0.9900544	best: 0.9900544 (504)	total: 54.1s	remaining: 53s
# 505:	test: 0.9900605	best: 0.9900605 (505)	total: 54.2s	remaining: 52.9s
# 506:	test: 0.9900811	best: 0.9900811 (506)	total: 54.3s	remaining: 52.8s
# 507:	test: 0.9900811	best: 0.9900811 (506)	total: 54.4s	remaining: 52.6s
# 508:	test: 0.9900883	best: 0.9900883 (508)	total: 54.4s	remaining: 52.5s
# 509:	test: 0.9900932	best: 0.9900932 (509)	total: 54.5s	remaining: 52.4s
# 510:	test: 0.9901085	best: 0.9901085 (510)	total: 54.6s	remaining: 52.3s
# 511:	test: 0.9901114	best: 0.9901114 (511)	total: 54.7s	remaining: 52.1s
# 512:	test: 0.9901164	best: 0.9901164 (512)	total: 54.8s	remaining: 52s
# 513:	test: 0.9901259	best: 0.9901259 (513)	total: 54.9s	remaining: 51.9s
# 514:	test: 0.9901320	best: 0.9901320 (514)	total: 55s	remaining: 51.8s
# 515:	test: 0.9901398	best: 0.9901398 (515)	total: 55.1s	remaining: 51.7s
# 516:	test: 0.9901567	best: 0.9901567 (516)	total: 55.2s	remaining: 51.5s
# 517:	test: 0.9901606	best: 0.9901606 (517)	total: 55.3s	remaining: 51.4s
# 518:	test: 0.9901661	best: 0.9901661 (518)	total: 55.4s	remaining: 51.3s
# 519:	test: 0.9901700	best: 0.9901700 (519)	total: 55.4s	remaining: 51.2s
# 520:	test: 0.9901757	best: 0.9901757 (520)	total: 55.5s	remaining: 51s
# 521:	test: 0.9901833	best: 0.9901833 (521)	total: 55.6s	remaining: 50.9s
# 522:	test: 0.9901862	best: 0.9901862 (522)	total: 55.7s	remaining: 50.8s
# 523:	test: 0.9901982	best: 0.9901982 (523)	total: 55.8s	remaining: 50.7s
# 524:	test: 0.9902135	best: 0.9902135 (524)	total: 55.9s	remaining: 50.6s
# 525:	test: 0.9902282	best: 0.9902282 (525)	total: 56s	remaining: 50.4s
# 526:	test: 0.9902381	best: 0.9902381 (526)	total: 56s	remaining: 50.3s
# 527:	test: 0.9902628	best: 0.9902628 (527)	total: 56.1s	remaining: 50.2s
# 528:	test: 0.9902686	best: 0.9902686 (528)	total: 56.2s	remaining: 50s
# 529:	test: 0.9902727	best: 0.9902727 (529)	total: 56.3s	remaining: 49.9s
# 530:	test: 0.9902784	best: 0.9902784 (530)	total: 56.8s	remaining: 50.2s
# 531:	test: 0.9902813	best: 0.9902813 (531)	total: 56.9s	remaining: 50.1s
# 532:	test: 0.9903066	best: 0.9903066 (532)	total: 57s	remaining: 49.9s
# 533:	test: 0.9903320	best: 0.9903320 (533)	total: 57.1s	remaining: 49.8s
# 534:	test: 0.9903462	best: 0.9903462 (534)	total: 57.2s	remaining: 49.7s
# 535:	test: 0.9903499	best: 0.9903499 (535)	total: 57.3s	remaining: 49.6s
# 536:	test: 0.9903563	best: 0.9903563 (536)	total: 57.4s	remaining: 49.5s
# 537:	test: 0.9903633	best: 0.9903633 (537)	total: 57.5s	remaining: 49.4s
# 538:	test: 0.9903692	best: 0.9903692 (538)	total: 57.6s	remaining: 49.2s
# 539:	test: 0.9903775	best: 0.9903775 (539)	total: 57.7s	remaining: 49.1s
# 540:	test: 0.9903842	best: 0.9903842 (540)	total: 57.8s	remaining: 49s
# 541:	test: 0.9903971	best: 0.9903971 (541)	total: 57.9s	remaining: 48.9s
# 542:	test: 0.9904008	best: 0.9904008 (542)	total: 58s	remaining: 48.8s
# 543:	test: 0.9904145	best: 0.9904145 (543)	total: 58.1s	remaining: 48.7s
# 544:	test: 0.9904204	best: 0.9904204 (544)	total: 58.2s	remaining: 48.6s
# 545:	test: 0.9904264	best: 0.9904264 (545)	total: 58.3s	remaining: 48.5s
# 546:	test: 0.9904343	best: 0.9904343 (546)	total: 58.4s	remaining: 48.3s
# 547:	test: 0.9904389	best: 0.9904389 (547)	total: 58.5s	remaining: 48.2s
# 548:	test: 0.9904473	best: 0.9904473 (548)	total: 58.6s	remaining: 48.1s
# 549:	test: 0.9904545	best: 0.9904545 (549)	total: 58.6s	remaining: 48s
# 550:	test: 0.9904647	best: 0.9904647 (550)	total: 59.3s	remaining: 48.3s
# 551:	test: 0.9904719	best: 0.9904719 (551)	total: 59.4s	remaining: 48.2s
# 552:	test: 0.9904866	best: 0.9904866 (552)	total: 59.5s	remaining: 48.1s
# 553:	test: 0.9904859	best: 0.9904866 (552)	total: 59.6s	remaining: 48s
# 554:	test: 0.9904912	best: 0.9904912 (554)	total: 59.7s	remaining: 47.9s
# 555:	test: 0.9904931	best: 0.9904931 (555)	total: 59.8s	remaining: 47.8s
# 556:	test: 0.9905046	best: 0.9905046 (556)	total: 59.9s	remaining: 47.6s
# 557:	test: 0.9905167	best: 0.9905167 (557)	total: 1m	remaining: 47.7s
# 558:	test: 0.9905204	best: 0.9905204 (558)	total: 1m	remaining: 47.6s
# 559:	test: 0.9905395	best: 0.9905395 (559)	total: 1m	remaining: 47.5s
# 560:	test: 0.9905426	best: 0.9905426 (560)	total: 1m	remaining: 47.4s
# 561:	test: 0.9905481	best: 0.9905481 (561)	total: 1m	remaining: 47.3s
# 562:	test: 0.9905549	best: 0.9905549 (562)	total: 1m	remaining: 47.2s
# 563:	test: 0.9905650	best: 0.9905650 (563)	total: 1m	remaining: 47s
# 564:	test: 0.9905893	best: 0.9905893 (564)	total: 1m	remaining: 46.9s
# 565:	test: 0.9905956	best: 0.9905956 (565)	total: 1m 1s	remaining: 46.8s
# 566:	test: 0.9905968	best: 0.9905968 (566)	total: 1m 1s	remaining: 46.7s
# 567:	test: 0.9906036	best: 0.9906036 (567)	total: 1m 1s	remaining: 46.6s
# 568:	test: 0.9906110	best: 0.9906110 (568)	total: 1m 1s	remaining: 46.4s
# 569:	test: 0.9906171	best: 0.9906171 (569)	total: 1m 1s	remaining: 46.6s
# 570:	test: 0.9906253	best: 0.9906253 (570)	total: 1m 1s	remaining: 46.5s
# 571:	test: 0.9906381	best: 0.9906381 (571)	total: 1m 1s	remaining: 46.3s
# 572:	test: 0.9906489	best: 0.9906489 (572)	total: 1m 2s	remaining: 46.2s
# 573:	test: 0.9906524	best: 0.9906524 (573)	total: 1m 2s	remaining: 46.1s
# 574:	test: 0.9906537	best: 0.9906537 (574)	total: 1m 2s	remaining: 46s
# 575:	test: 0.9906681	best: 0.9906681 (575)	total: 1m 2s	remaining: 45.9s
# 576:	test: 0.9906707	best: 0.9906707 (576)	total: 1m 2s	remaining: 45.7s
# 577:	test: 0.9906797	best: 0.9906797 (577)	total: 1m 2s	remaining: 45.6s
# 578:	test: 0.9906857	best: 0.9906857 (578)	total: 1m 2s	remaining: 45.5s
# 579:	test: 0.9906921	best: 0.9906921 (579)	total: 1m 2s	remaining: 45.4s
# 580:	test: 0.9907014	best: 0.9907014 (580)	total: 1m 2s	remaining: 45.3s
# 581:	test: 0.9907049	best: 0.9907049 (581)	total: 1m 2s	remaining: 45.1s
# 582:	test: 0.9907087	best: 0.9907087 (582)	total: 1m 2s	remaining: 45s
# 583:	test: 0.9907257	best: 0.9907257 (583)	total: 1m 3s	remaining: 44.9s
# 584:	test: 0.9907357	best: 0.9907357 (584)	total: 1m 3s	remaining: 44.8s
# 585:	test: 0.9907421	best: 0.9907421 (585)	total: 1m 3s	remaining: 44.7s
# 586:	test: 0.9907531	best: 0.9907531 (586)	total: 1m 3s	remaining: 44.5s
# 587:	test: 0.9907748	best: 0.9907748 (587)	total: 1m 3s	remaining: 44.4s
# 588:	test: 0.9907845	best: 0.9907845 (588)	total: 1m 3s	remaining: 44.3s
# 589:	test: 0.9907873	best: 0.9907873 (589)	total: 1m 3s	remaining: 44.2s
# 590:	test: 0.9908057	best: 0.9908057 (590)	total: 1m 3s	remaining: 44.1s
# 591:	test: 0.9908114	best: 0.9908114 (591)	total: 1m 3s	remaining: 43.9s
# 592:	test: 0.9908205	best: 0.9908205 (592)	total: 1m 3s	remaining: 43.8s
# 593:	test: 0.9908337	best: 0.9908337 (593)	total: 1m 3s	remaining: 43.7s
# 594:	test: 0.9908347	best: 0.9908347 (594)	total: 1m 4s	remaining: 43.6s
# 595:	test: 0.9908446	best: 0.9908446 (595)	total: 1m 4s	remaining: 43.5s
# 596:	test: 0.9908506	best: 0.9908506 (596)	total: 1m 4s	remaining: 43.4s
# 597:	test: 0.9908625	best: 0.9908625 (597)	total: 1m 4s	remaining: 43.3s
# 598:	test: 0.9908670	best: 0.9908670 (598)	total: 1m 4s	remaining: 43.1s
# 599:	test: 0.9908813	best: 0.9908813 (599)	total: 1m 4s	remaining: 43s
# 600:	test: 0.9908898	best: 0.9908898 (600)	total: 1m 4s	remaining: 42.9s
# 601:	test: 0.9908916	best: 0.9908916 (601)	total: 1m 4s	remaining: 42.8s
# 602:	test: 0.9908990	best: 0.9908990 (602)	total: 1m 4s	remaining: 42.7s
# 603:	test: 0.9909034	best: 0.9909034 (603)	total: 1m 4s	remaining: 42.6s
# 604:	test: 0.9909112	best: 0.9909112 (604)	total: 1m 4s	remaining: 42.4s
# 605:	test: 0.9909120	best: 0.9909120 (605)	total: 1m 5s	remaining: 42.3s
# 606:	test: 0.9909247	best: 0.9909247 (606)	total: 1m 5s	remaining: 42.2s
# 607:	test: 0.9909360	best: 0.9909360 (607)	total: 1m 5s	remaining: 42.1s
# 608:	test: 0.9909599	best: 0.9909599 (608)	total: 1m 5s	remaining: 42s
# 609:	test: 0.9909656	best: 0.9909656 (609)	total: 1m 5s	remaining: 41.8s
# 610:	test: 0.9909878	best: 0.9909878 (610)	total: 1m 5s	remaining: 41.7s
# 611:	test: 0.9910012	best: 0.9910012 (611)	total: 1m 5s	remaining: 41.6s
# 612:	test: 0.9910098	best: 0.9910098 (612)	total: 1m 5s	remaining: 41.5s
# 613:	test: 0.9910121	best: 0.9910121 (613)	total: 1m 5s	remaining: 41.4s
# 614:	test: 0.9910215	best: 0.9910215 (614)	total: 1m 5s	remaining: 41.3s
# 615:	test: 0.9910268	best: 0.9910268 (615)	total: 1m 6s	remaining: 41.2s
# 616:	test: 0.9910330	best: 0.9910330 (616)	total: 1m 6s	remaining: 41s
# 617:	test: 0.9910403	best: 0.9910403 (617)	total: 1m 6s	remaining: 40.9s
# 618:	test: 0.9910470	best: 0.9910470 (618)	total: 1m 6s	remaining: 40.8s
# 619:	test: 0.9910596	best: 0.9910596 (619)	total: 1m 6s	remaining: 40.9s
# 620:	test: 0.9910723	best: 0.9910723 (620)	total: 1m 6s	remaining: 40.8s
# 621:	test: 0.9910772	best: 0.9910772 (621)	total: 1m 6s	remaining: 40.7s
# 622:	test: 0.9910799	best: 0.9910799 (622)	total: 1m 7s	remaining: 40.6s
# 623:	test: 0.9910847	best: 0.9910847 (623)	total: 1m 7s	remaining: 40.5s
# 624:	test: 0.9910908	best: 0.9910908 (624)	total: 1m 7s	remaining: 40.4s
# 625:	test: 0.9910974	best: 0.9910974 (625)	total: 1m 7s	remaining: 40.3s
# 626:	test: 0.9910998	best: 0.9910998 (626)	total: 1m 7s	remaining: 40.1s
# 627:	test: 0.9911042	best: 0.9911042 (627)	total: 1m 7s	remaining: 40s
# 628:	test: 0.9911075	best: 0.9911075 (628)	total: 1m 7s	remaining: 39.9s
# 629:	test: 0.9911130	best: 0.9911130 (629)	total: 1m 7s	remaining: 39.8s
# 630:	test: 0.9911314	best: 0.9911314 (630)	total: 1m 7s	remaining: 39.7s
# 631:	test: 0.9911391	best: 0.9911391 (631)	total: 1m 7s	remaining: 39.6s
# 632:	test: 0.9911465	best: 0.9911465 (632)	total: 1m 8s	remaining: 39.5s
# 633:	test: 0.9911516	best: 0.9911516 (633)	total: 1m 8s	remaining: 39.3s
# 634:	test: 0.9911577	best: 0.9911577 (634)	total: 1m 8s	remaining: 39.2s
# 635:	test: 0.9911671	best: 0.9911671 (635)	total: 1m 8s	remaining: 39.1s
# 636:	test: 0.9911783	best: 0.9911783 (636)	total: 1m 8s	remaining: 39s
# 637:	test: 0.9911863	best: 0.9911863 (637)	total: 1m 8s	remaining: 38.9s
# 638:	test: 0.9911921	best: 0.9911921 (638)	total: 1m 8s	remaining: 38.8s
# 639:	test: 0.9912015	best: 0.9912015 (639)	total: 1m 8s	remaining: 38.6s
# 640:	test: 0.9912092	best: 0.9912092 (640)	total: 1m 8s	remaining: 38.5s
# 641:	test: 0.9912167	best: 0.9912167 (641)	total: 1m 8s	remaining: 38.4s
# 642:	test: 0.9912219	best: 0.9912219 (642)	total: 1m 8s	remaining: 38.3s
# 643:	test: 0.9912374	best: 0.9912374 (643)	total: 1m 9s	remaining: 38.2s
# 644:	test: 0.9912454	best: 0.9912454 (644)	total: 1m 9s	remaining: 38.1s
# 645:	test: 0.9912549	best: 0.9912549 (645)	total: 1m 9s	remaining: 37.9s
# 646:	test: 0.9912589	best: 0.9912589 (646)	total: 1m 9s	remaining: 37.8s
# 647:	test: 0.9912799	best: 0.9912799 (647)	total: 1m 9s	remaining: 37.7s
# 648:	test: 0.9912857	best: 0.9912857 (648)	total: 1m 9s	remaining: 37.6s
# 649:	test: 0.9912913	best: 0.9912913 (649)	total: 1m 9s	remaining: 37.5s
# 650:	test: 0.9912981	best: 0.9912981 (650)	total: 1m 9s	remaining: 37.4s
# 651:	test: 0.9913166	best: 0.9913166 (651)	total: 1m 9s	remaining: 37.3s
# 652:	test: 0.9913268	best: 0.9913268 (652)	total: 1m 9s	remaining: 37.2s
# 653:	test: 0.9913275	best: 0.9913275 (653)	total: 1m 10s	remaining: 37s
# 654:	test: 0.9913308	best: 0.9913308 (654)	total: 1m 10s	remaining: 36.9s
# 655:	test: 0.9913408	best: 0.9913408 (655)	total: 1m 10s	remaining: 36.8s
# 656:	test: 0.9913444	best: 0.9913444 (656)	total: 1m 10s	remaining: 36.7s
# 657:	test: 0.9913474	best: 0.9913474 (657)	total: 1m 10s	remaining: 36.6s
# ...
# 54:	test: 0.9951350	best: 0.9951357 (53)	total: 6.9s	remaining: 1m 58s
# 55:	test: 0.9951597	best: 0.9951597 (55)	total: 7.23s	remaining: 2m 1s
# 56:	test: 0.9951737	best: 0.9951737 (56)	total: 7.37s	remaining: 2m 1s
# 57:	test: 0.9952077	best: 0.9952077 (57)	total: 7.5s	remaining: 2m 1s
# 58:	test: 0.9951954	best: 0.9952077 (57)	total: 7.52s	remaining: 1m 59s
# 59:	test: 0.9952578	best: 0.9952578 (59)	total: 7.55s	remaining: 1m 58s
# 60:	test: 0.9952628	best: 0.9952628 (60)	total: 7.57s	remaining: 1m 56s
# 61:	test: 0.9952709	best: 0.9952709 (61)	total: 7.59s	remaining: 1m 54s
# 62:	test: 0.9953161	best: 0.9953161 (62)	total: 7.61s	remaining: 1m 53s
# 63:	test: 0.9953155	best: 0.9953161 (62)	total: 7.63s	remaining: 1m 51s
# 64:	test: 0.9953156	best: 0.9953161 (62)	total: 7.64s	remaining: 1m 49s
# 65:	test: 0.9953468	best: 0.9953468 (65)	total: 7.67s	remaining: 1m 48s
# 66:	test: 0.9953860	best: 0.9953860 (66)	total: 7.69s	remaining: 1m 47s
# 67:	test: 0.9954201	best: 0.9954201 (67)	total: 7.71s	remaining: 1m 45s
# 68:	test: 0.9954534	best: 0.9954534 (68)	total: 7.73s	remaining: 1m 44s
# 69:	test: 0.9954910	best: 0.9954910 (69)	total: 7.76s	remaining: 1m 43s
# 70:	test: 0.9955037	best: 0.9955037 (70)	total: 7.78s	remaining: 1m 41s
# 71:	test: 0.9955882	best: 0.9955882 (71)	total: 7.8s	remaining: 1m 40s
# 72:	test: 0.9955882	best: 0.9955882 (71)	total: 7.81s	remaining: 1m 39s
# 73:	test: 0.9956937	best: 0.9956937 (73)	total: 7.83s	remaining: 1m 37s
# 74:	test: 0.9957304	best: 0.9957304 (74)	total: 7.85s	remaining: 1m 36s
# 75:	test: 0.9957640	best: 0.9957640 (75)	total: 7.87s	remaining: 1m 35s
# 76:	test: 0.9957802	best: 0.9957802 (76)	total: 7.88s	remaining: 1m 34s
# 77:	test: 0.9957873	best: 0.9957873 (77)	total: 7.9s	remaining: 1m 33s
# 78:	test: 0.9958184	best: 0.9958184 (78)	total: 7.96s	remaining: 1m 32s
# 79:	test: 0.9958288	best: 0.9958288 (79)	total: 7.97s	remaining: 1m 31s
# 80:	test: 0.9958436	best: 0.9958436 (80)	total: 8.01s	remaining: 1m 30s
# 81:	test: 0.9958617	best: 0.9958617 (81)	total: 8.03s	remaining: 1m 29s
# 82:	test: 0.9959061	best: 0.9959061 (82)	total: 8.05s	remaining: 1m 28s
# 83:	test: 0.9959097	best: 0.9959097 (83)	total: 8.07s	remaining: 1m 27s
# 84:	test: 0.9959205	best: 0.9959205 (84)	total: 8.08s	remaining: 1m 27s
# 85:	test: 0.9959259	best: 0.9959259 (85)	total: 8.1s	remaining: 1m 26s
# 86:	test: 0.9959652	best: 0.9959652 (86)	total: 8.12s	remaining: 1m 25s
# 87:	test: 0.9959736	best: 0.9959736 (87)	total: 8.14s	remaining: 1m 24s
# 88:	test: 0.9960152	best: 0.9960152 (88)	total: 8.15s	remaining: 1m 23s
# 89:	test: 0.9960551	best: 0.9960551 (89)	total: 8.18s	remaining: 1m 22s
# 90:	test: 0.9960768	best: 0.9960768 (90)	total: 8.2s	remaining: 1m 21s
# 91:	test: 0.9960859	best: 0.9960859 (91)	total: 8.22s	remaining: 1m 21s
# 92:	test: 0.9960867	best: 0.9960867 (92)	total: 8.23s	remaining: 1m 20s
# 93:	test: 0.9961254	best: 0.9961254 (93)	total: 8.25s	remaining: 1m 19s
# 94:	test: 0.9961425	best: 0.9961425 (94)	total: 8.27s	remaining: 1m 18s
# 95:	test: 0.9961327	best: 0.9961425 (94)	total: 8.28s	remaining: 1m 18s
# 96:	test: 0.9961830	best: 0.9961830 (96)	total: 8.3s	remaining: 1m 17s
# 97:	test: 0.9961873	best: 0.9961873 (97)	total: 8.31s	remaining: 1m 16s
# 98:	test: 0.9962140	best: 0.9962140 (98)	total: 8.33s	remaining: 1m 15s
# 99:	test: 0.9962397	best: 0.9962397 (99)	total: 8.34s	remaining: 1m 15s
# 100:	test: 0.9962405	best: 0.9962405 (100)	total: 8.36s	remaining: 1m 14s
# 101:	test: 0.9962403	best: 0.9962405 (100)	total: 8.37s	remaining: 1m 13s
# 102:	test: 0.9962829	best: 0.9962829 (102)	total: 8.4s	remaining: 1m 13s
# 103:	test: 0.9963114	best: 0.9963114 (103)	total: 8.42s	remaining: 1m 12s
# 104:	test: 0.9963113	best: 0.9963114 (103)	total: 8.43s	remaining: 1m 11s
# 105:	test: 0.9963149	best: 0.9963149 (105)	total: 8.45s	remaining: 1m 11s
# 106:	test: 0.9963218	best: 0.9963218 (106)	total: 8.46s	remaining: 1m 10s
# 107:	test: 0.9963200	best: 0.9963218 (106)	total: 8.48s	remaining: 1m 10s
# 108:	test: 0.9963318	best: 0.9963318 (108)	total: 8.5s	remaining: 1m 9s
# 109:	test: 0.9963346	best: 0.9963346 (109)	total: 8.51s	remaining: 1m 8s
# 110:	test: 0.9963559	best: 0.9963559 (110)	total: 8.53s	remaining: 1m 8s
# 111:	test: 0.9963744	best: 0.9963744 (111)	total: 8.56s	remaining: 1m 7s
# 112:	test: 0.9963841	best: 0.9963841 (112)	total: 8.58s	remaining: 1m 7s
# 113:	test: 0.9963850	best: 0.9963850 (113)	total: 8.6s	remaining: 1m 6s
# 114:	test: 0.9963987	best: 0.9963987 (114)	total: 8.65s	remaining: 1m 6s
# 115:	test: 0.9964110	best: 0.9964110 (115)	total: 8.67s	remaining: 1m 6s
# 116:	test: 0.9964305	best: 0.9964305 (116)	total: 8.69s	remaining: 1m 5s
# 117:	test: 0.9964486	best: 0.9964486 (117)	total: 8.71s	remaining: 1m 5s
# 118:	test: 0.9964622	best: 0.9964622 (118)	total: 8.73s	remaining: 1m 4s
# 119:	test: 0.9964646	best: 0.9964646 (119)	total: 8.74s	remaining: 1m 4s
# 120:	test: 0.9964850	best: 0.9964850 (120)	total: 8.76s	remaining: 1m 3s
# 121:	test: 0.9964851	best: 0.9964851 (121)	total: 8.77s	remaining: 1m 3s
# 122:	test: 0.9964993	best: 0.9964993 (122)	total: 8.79s	remaining: 1m 2s
# 123:	test: 0.9965058	best: 0.9965058 (123)	total: 8.81s	remaining: 1m 2s
# 124:	test: 0.9965210	best: 0.9965210 (124)	total: 8.85s	remaining: 1m 1s
# 125:	test: 0.9965334	best: 0.9965334 (125)	total: 8.87s	remaining: 1m 1s
# 126:	test: 0.9965382	best: 0.9965382 (126)	total: 8.89s	remaining: 1m 1s
# 127:	test: 0.9965521	best: 0.9965521 (127)	total: 8.92s	remaining: 1m
# 128:	test: 0.9965561	best: 0.9965561 (128)	total: 8.95s	remaining: 1m
# 129:	test: 0.9965794	best: 0.9965794 (129)	total: 8.97s	remaining: 1m
# 130:	test: 0.9965822	best: 0.9965822 (130)	total: 8.99s	remaining: 59.7s
# 131:	test: 0.9965878	best: 0.9965878 (131)	total: 9.06s	remaining: 59.6s
# 132:	test: 0.9966093	best: 0.9966093 (132)	total: 9.11s	remaining: 59.4s
# 133:	test: 0.9966127	best: 0.9966127 (133)	total: 9.13s	remaining: 59s
# 134:	test: 0.9966149	best: 0.9966149 (134)	total: 9.15s	remaining: 58.7s
# 135:	test: 0.9966356	best: 0.9966356 (135)	total: 9.17s	remaining: 58.3s
# 136:	test: 0.9966289	best: 0.9966356 (135)	total: 9.2s	remaining: 57.9s
# 137:	test: 0.9966269	best: 0.9966356 (135)	total: 9.22s	remaining: 57.6s
# 138:	test: 0.9966287	best: 0.9966356 (135)	total: 9.26s	remaining: 57.3s
# 139:	test: 0.9966500	best: 0.9966500 (139)	total: 9.3s	remaining: 57.1s
# 140:	test: 0.9966555	best: 0.9966555 (140)	total: 9.34s	remaining: 56.9s
# 141:	test: 0.9966607	best: 0.9966607 (141)	total: 9.41s	remaining: 56.8s
# 142:	test: 0.9966691	best: 0.9966691 (142)	total: 9.43s	remaining: 56.5s
# 143:	test: 0.9966836	best: 0.9966836 (143)	total: 9.44s	remaining: 56.1s
# 144:	test: 0.9966861	best: 0.9966861 (144)	total: 9.46s	remaining: 55.8s
# 145:	test: 0.9967200	best: 0.9967200 (145)	total: 9.48s	remaining: 55.5s
# 146:	test: 0.9967158	best: 0.9967200 (145)	total: 9.51s	remaining: 55.2s
# 147:	test: 0.9967241	best: 0.9967241 (147)	total: 9.55s	remaining: 55s
# 148:	test: 0.9967236	best: 0.9967241 (147)	total: 9.58s	remaining: 54.7s
# 149:	test: 0.9967367	best: 0.9967367 (149)	total: 9.61s	remaining: 54.4s
# 150:	test: 0.9967341	best: 0.9967367 (149)	total: 9.64s	remaining: 54.2s
# 151:	test: 0.9967326	best: 0.9967367 (149)	total: 9.66s	remaining: 53.9s
# 152:	test: 0.9967319	best: 0.9967367 (149)	total: 9.68s	remaining: 53.6s
# 153:	test: 0.9967316	best: 0.9967367 (149)	total: 9.71s	remaining: 53.3s
# 154:	test: 0.9967353	best: 0.9967367 (149)	total: 9.75s	remaining: 53.1s
# 155:	test: 0.9967427	best: 0.9967427 (155)	total: 9.78s	remaining: 52.9s
# 156:	test: 0.9967584	best: 0.9967584 (156)	total: 9.81s	remaining: 52.7s
# 157:	test: 0.9967583	best: 0.9967584 (156)	total: 9.83s	remaining: 52.4s
# 158:	test: 0.9967640	best: 0.9967640 (158)	total: 9.86s	remaining: 52.1s
# 159:	test: 0.9967829	best: 0.9967829 (159)	total: 9.89s	remaining: 51.9s
# 160:	test: 0.9967839	best: 0.9967839 (160)	total: 9.91s	remaining: 51.7s
# 161:	test: 0.9967896	best: 0.9967896 (161)	total: 9.94s	remaining: 51.4s
# 162:	test: 0.9967831	best: 0.9967896 (161)	total: 9.96s	remaining: 51.2s
# 163:	test: 0.9967882	best: 0.9967896 (161)	total: 10s	remaining: 51.1s
# 164:	test: 0.9967950	best: 0.9967950 (164)	total: 10.1s	remaining: 50.9s
# 165:	test: 0.9967932	best: 0.9967950 (164)	total: 10.1s	remaining: 50.6s
# 166:	test: 0.9968000	best: 0.9968000 (166)	total: 10.1s	remaining: 50.3s
# 167:	test: 0.9968001	best: 0.9968001 (167)	total: 10.1s	remaining: 50.1s
# 168:	test: 0.9968042	best: 0.9968042 (168)	total: 10.1s	remaining: 49.8s
# 169:	test: 0.9968145	best: 0.9968145 (169)	total: 10.2s	remaining: 49.6s
# 170:	test: 0.9968205	best: 0.9968205 (170)	total: 10.2s	remaining: 49.4s
# 171:	test: 0.9968177	best: 0.9968205 (170)	total: 10.2s	remaining: 49.2s
# 172:	test: 0.9968219	best: 0.9968219 (172)	total: 10.4s	remaining: 49.6s
# 173:	test: 0.9968348	best: 0.9968348 (173)	total: 10.8s	remaining: 51.3s
# 174:	test: 0.9968430	best: 0.9968430 (174)	total: 11s	remaining: 51.9s
# 175:	test: 0.9968496	best: 0.9968496 (175)	total: 11.1s	remaining: 52s
# 176:	test: 0.9968522	best: 0.9968522 (176)	total: 11.5s	remaining: 53.3s
# 177:	test: 0.9968522	best: 0.9968522 (177)	total: 11.6s	remaining: 53.4s
# 178:	test: 0.9968523	best: 0.9968523 (178)	total: 11.7s	remaining: 53.5s
# 179:	test: 0.9968531	best: 0.9968531 (179)	total: 11.8s	remaining: 53.8s
# 180:	test: 0.9968536	best: 0.9968536 (180)	total: 12s	remaining: 54.1s
# 181:	test: 0.9968544	best: 0.9968544 (181)	total: 12.1s	remaining: 54.3s
# 182:	test: 0.9968806	best: 0.9968806 (182)	total: 12.2s	remaining: 54.7s
# 183:	test: 0.9968874	best: 0.9968874 (183)	total: 12.3s	remaining: 54.5s
# 184:	test: 0.9968959	best: 0.9968959 (184)	total: 12.3s	remaining: 54.2s
# 185:	test: 0.9969162	best: 0.9969162 (185)	total: 12.3s	remaining: 54s
# 186:	test: 0.9969232	best: 0.9969232 (186)	total: 12.3s	remaining: 53.7s
# 187:	test: 0.9969234	best: 0.9969234 (187)	total: 12.4s	remaining: 53.4s
# 188:	test: 0.9969234	best: 0.9969234 (188)	total: 12.4s	remaining: 53.1s
# 189:	test: 0.9969295	best: 0.9969295 (189)	total: 12.4s	remaining: 52.8s
# 190:	test: 0.9969337	best: 0.9969337 (190)	total: 12.4s	remaining: 52.6s
# 191:	test: 0.9969433	best: 0.9969433 (191)	total: 12.4s	remaining: 52.3s
# 192:	test: 0.9969430	best: 0.9969433 (191)	total: 12.4s	remaining: 52s
# 193:	test: 0.9969467	best: 0.9969467 (193)	total: 12.5s	remaining: 51.8s
# 194:	test: 0.9969504	best: 0.9969504 (194)	total: 12.5s	remaining: 51.5s
# 195:	test: 0.9969600	best: 0.9969600 (195)	total: 12.5s	remaining: 51.3s
# 196:	test: 0.9969592	best: 0.9969600 (195)	total: 12.5s	remaining: 51s
# 197:	test: 0.9969634	best: 0.9969634 (197)	total: 12.5s	remaining: 50.8s
# 198:	test: 0.9969678	best: 0.9969678 (198)	total: 12.6s	remaining: 50.5s
# 199:	test: 0.9969736	best: 0.9969736 (199)	total: 12.6s	remaining: 50.3s
# 200:	test: 0.9969726	best: 0.9969736 (199)	total: 12.6s	remaining: 50s
# 201:	test: 0.9969844	best: 0.9969844 (201)	total: 12.6s	remaining: 49.8s
# 202:	test: 0.9970058	best: 0.9970058 (202)	total: 12.6s	remaining: 49.5s
# 203:	test: 0.9970068	best: 0.9970068 (203)	total: 12.6s	remaining: 49.3s
# 204:	test: 0.9970129	best: 0.9970129 (204)	total: 12.7s	remaining: 49.1s
# 205:	test: 0.9970130	best: 0.9970130 (205)	total: 12.7s	remaining: 48.8s
# 206:	test: 0.9970180	best: 0.9970180 (206)	total: 12.7s	remaining: 48.7s
# 207:	test: 0.9970343	best: 0.9970343 (207)	total: 12.7s	remaining: 48.5s
# 208:	test: 0.9970420	best: 0.9970420 (208)	total: 12.8s	remaining: 48.3s
# 209:	test: 0.9970543	best: 0.9970543 (209)	total: 12.8s	remaining: 48s
# 210:	test: 0.9970465	best: 0.9970543 (209)	total: 12.8s	remaining: 47.8s
# 211:	test: 0.9970463	best: 0.9970543 (209)	total: 12.8s	remaining: 47.6s
# 212:	test: 0.9970771	best: 0.9970771 (212)	total: 12.8s	remaining: 47.4s
# 213:	test: 0.9970771	best: 0.9970771 (212)	total: 12.8s	remaining: 47.1s
# 214:	test: 0.9971003	best: 0.9971003 (214)	total: 12.9s	remaining: 47s
# 215:	test: 0.9971088	best: 0.9971088 (215)	total: 12.9s	remaining: 46.8s
# 216:	test: 0.9971140	best: 0.9971140 (216)	total: 12.9s	remaining: 46.6s
# 217:	test: 0.9971136	best: 0.9971140 (216)	total: 12.9s	remaining: 46.4s
# 218:	test: 0.9971135	best: 0.9971140 (216)	total: 12.9s	remaining: 46.2s
# 219:	test: 0.9971196	best: 0.9971196 (219)	total: 13s	remaining: 45.9s
# 220:	test: 0.9971186	best: 0.9971196 (219)	total: 13s	remaining: 45.7s
# 221:	test: 0.9971268	best: 0.9971268 (221)	total: 13s	remaining: 45.5s
# 222:	test: 0.9971412	best: 0.9971412 (222)	total: 13s	remaining: 45.3s
# 223:	test: 0.9971287	best: 0.9971412 (222)	total: 13s	remaining: 45.1s
# 224:	test: 0.9971288	best: 0.9971412 (222)	total: 13s	remaining: 44.9s
# 225:	test: 0.9971461	best: 0.9971461 (225)	total: 13.1s	remaining: 44.7s
# 226:	test: 0.9971460	best: 0.9971461 (225)	total: 13.1s	remaining: 44.5s
# 227:	test: 0.9971449	best: 0.9971461 (225)	total: 13.1s	remaining: 44.3s
# 228:	test: 0.9971478	best: 0.9971478 (228)	total: 13.1s	remaining: 44.2s
# 229:	test: 0.9971381	best: 0.9971478 (228)	total: 13.1s	remaining: 44s
# 230:	test: 0.9971515	best: 0.9971515 (230)	total: 13.2s	remaining: 43.8s
# 231:	test: 0.9971605	best: 0.9971605 (231)	total: 13.2s	remaining: 43.6s
# 232:	test: 0.9971490	best: 0.9971605 (231)	total: 13.2s	remaining: 43.4s
# 233:	test: 0.9971544	best: 0.9971605 (231)	total: 13.2s	remaining: 43.2s
# 234:	test: 0.9971547	best: 0.9971605 (231)	total: 13.2s	remaining: 43.1s
# 235:	test: 0.9971653	best: 0.9971653 (235)	total: 13.2s	remaining: 42.9s
# 236:	test: 0.9971642	best: 0.9971653 (235)	total: 13.3s	remaining: 42.7s
# 237:	test: 0.9971643	best: 0.9971653 (235)	total: 13.3s	remaining: 42.5s
# 238:	test: 0.9971711	best: 0.9971711 (238)	total: 13.3s	remaining: 42.3s
# 239:	test: 0.9971767	best: 0.9971767 (239)	total: 13.3s	remaining: 42.1s
# 240:	test: 0.9971789	best: 0.9971789 (240)	total: 13.3s	remaining: 42s
# 241:	test: 0.9971828	best: 0.9971828 (241)	total: 13.3s	remaining: 41.8s
# 242:	test: 0.9971869	best: 0.9971869 (242)	total: 13.4s	remaining: 41.6s
# 243:	test: 0.9971883	best: 0.9971883 (243)	total: 13.4s	remaining: 41.5s
# 244:	test: 0.9971978	best: 0.9971978 (244)	total: 13.4s	remaining: 41.3s
# 245:	test: 0.9971971	best: 0.9971978 (244)	total: 13.4s	remaining: 41.1s
# 246:	test: 0.9972187	best: 0.9972187 (246)	total: 13.4s	remaining: 40.9s
# 247:	test: 0.9972203	best: 0.9972203 (247)	total: 13.4s	remaining: 40.8s
# 248:	test: 0.9972256	best: 0.9972256 (248)	total: 13.5s	remaining: 40.6s
# 249:	test: 0.9972242	best: 0.9972256 (248)	total: 13.5s	remaining: 40.4s
# 250:	test: 0.9972342	best: 0.9972342 (250)	total: 13.5s	remaining: 40.3s
# 251:	test: 0.9972342	best: 0.9972342 (250)	total: 13.5s	remaining: 40.1s
# 252:	test: 0.9972342	best: 0.9972342 (250)	total: 13.5s	remaining: 40s
# 253:	test: 0.9972343	best: 0.9972343 (253)	total: 13.5s	remaining: 39.8s
# 254:	test: 0.9972402	best: 0.9972402 (254)	total: 13.6s	remaining: 39.6s
# 255:	test: 0.9972471	best: 0.9972471 (255)	total: 13.6s	remaining: 39.5s
# 256:	test: 0.9972507	best: 0.9972507 (256)	total: 13.6s	remaining: 39.3s
# 257:	test: 0.9972509	best: 0.9972509 (257)	total: 13.6s	remaining: 39.2s
# 258:	test: 0.9972491	best: 0.9972509 (257)	total: 13.6s	remaining: 39s
# 259:	test: 0.9972713	best: 0.9972713 (259)	total: 13.7s	remaining: 38.9s
# 260:	test: 0.9972815	best: 0.9972815 (260)	total: 13.7s	remaining: 38.7s
# 261:	test: 0.9972883	best: 0.9972883 (261)	total: 13.7s	remaining: 38.5s
# 262:	test: 0.9972884	best: 0.9972884 (262)	total: 13.7s	remaining: 38.4s
# 263:	test: 0.9972886	best: 0.9972886 (263)	total: 13.7s	remaining: 38.2s
# 264:	test: 0.9972805	best: 0.9972886 (263)	total: 13.8s	remaining: 38.1s
# 265:	test: 0.9972698	best: 0.9972886 (263)	total: 13.8s	remaining: 38s
# 266:	test: 0.9972697	best: 0.9972886 (263)	total: 13.8s	remaining: 37.9s
# 267:	test: 0.9972692	best: 0.9972886 (263)	total: 13.8s	remaining: 37.7s
# 268:	test: 0.9972632	best: 0.9972886 (263)	total: 14s	remaining: 37.9s
# 269:	test: 0.9972672	best: 0.9972886 (263)	total: 14s	remaining: 37.8s
# 270:	test: 0.9972720	best: 0.9972886 (263)	total: 14s	remaining: 37.7s
# 271:	test: 0.9972734	best: 0.9972886 (263)	total: 14s	remaining: 37.5s
# 272:	test: 0.9972734	best: 0.9972886 (263)	total: 14s	remaining: 37.4s
# 273:	test: 0.9972728	best: 0.9972886 (263)	total: 14.1s	remaining: 37.2s
#
# bestTest = 0.9972885564
# bestIteration = 263

# %%
# Checking if model is fitted
catboost_clf.is_fitted()
# Out:
# True

# %%
# Showing best params
catboost_clf.get_params()
# Out:
# {'iterations': 1000,
#  'loss_function': 'Logloss',
#  'random_seed': 42,
#  'class_weights': array([0.78561644, 1.37529976]),
#  'eval_metric': 'AUC',
#  'early_stopping_rounds': 10,
#  'min_data_in_leaf': 15,
#  'depth': 5,
#  'l2_leaf_reg': 3,
#  'learning_rate': 0.3}

# %%
# Making predictions
print('Predictions for Gradient Boosting')
train_preds = catboost_clf.predict_proba(X_train)[:,1]
valid_preds = catboost_clf.predict_proba(X_valid)[:,1]
train_score = roc_auc_score(y_train,train_preds)
valid_score = roc_auc_score(y_valid,valid_preds)
print(f'Training ROC AUC: {train_score}')
print(f'Validation ROC AUC: {valid_score}')
# Out:
# Predictions for Gradient Boosting
# Training ROC AUC: 0.9999597242041011
# Validation ROC AUC: 0.9715287627410495

# %%
# Adding the metrics
model = 'Gradient Boosting'
performances['model'].append(model)
performances['Train ROC AUC'].append(train_score)
performances['Valid ROC AUC'].append(valid_score)

# %%
catboost_clf.save_model('../../models/custom-features/noisy-grammar-errors/fine-tuned/catboost-noisy-fine')

# %%
# Printing out the model performances in a dataframe and saving it
metrics_df = pd.DataFrame().from_dict(performances)
metrics_df
# Out:
#                model  Train ROC AUC  Valid ROC AUC
# 0      Random Forest       0.988405       0.976345
# 1  Gradient Boosting       0.999960       0.971529

# %%
# Saving the performances
metrics_df.to_csv('../../models/custom-features/noisy-grammar-errors/fine-tuned/metrics.csv',index=False)
